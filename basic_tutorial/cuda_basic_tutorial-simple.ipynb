# %% [markdown]
# <a href="https://githubtocolab.com/chiyanglin-AStar/Cuda_Colab_study/blob/master/basic_tutorial/cuda_basic_tutorial-simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %% [markdown]
# # Install Nvidia & other dependencies
#
# in this version , remove colab have built-in package install steps

# %%
! add-apt-repository ppa:graphics-drivers/ppa
! apt update
! apt -y install nvidia-384 nvidia-384-dev
! apt-get -y install g++ freeglut3-dev build-essential libx11-dev libxmu-dev libxi-dev libglu1-mesa libglu1-mesa-dev
# Out:
# ^C
# Get:1 file:/var/cuda-repo-9-2-local  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 261 kB in 2s (120 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 20 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  cuda-drivers : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  libcuda1-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-384 : Depends: nvidia-driver-390 but it is not going to be installed
#  nvidia-384-dev : Depends: nvidia-driver-390 but it is not going to be installed
#  nvidia-396-dev : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-opencl-icd-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libglu1-mesa is already the newest version (9.0.0-2.1build1).
# libglu1-mesa set to manually installed.
# libglu1-mesa-dev is already the newest version (9.0.0-2.1build1).
# libglu1-mesa-dev set to manually installed.
# libxi-dev is already the newest version (2:1.7.9-1).
# libxi-dev set to manually installed.
# libxmu-dev is already the newest version (2:1.1.2-2).
# libxmu-dev set to manually installed.
# freeglut3-dev is already the newest version (2.8.1-3).
# freeglut3-dev set to manually installed.
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# libx11-dev is already the newest version (2:1.6.4-3ubuntu0.4).
# libx11-dev set to manually installed.
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  cuda-drivers : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  libcuda1-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-396-dev : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-opencl-icd-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %% [markdown]
# # Show our GPU

# %%
! nvidia-smi
# Out:
# Mon Sep 26 03:19:46 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # C Compiler

# %%
# !gcc -v
# Out:
# Using built-in specs.
# COLLECT_GCC=gcc
# COLLECT_LTO_WRAPPER=/usr/lib/gcc/x86_64-linux-gnu/7/lto-wrapper
# OFFLOAD_TARGET_NAMES=nvptx-none
# OFFLOAD_TARGET_DEFAULT=1
# Target: x86_64-linux-gnu
# Configured with: ../src/configure -v --with-pkgversion='Ubuntu 7.5.0-3ubuntu1~18.04' --with-bugurl=file:///usr/share/doc/gcc-7/README.Bugs --enable-languages=c,ada,c++,go,brig,d,fortran,objc,obj-c++ --prefix=/usr --with-gcc-major-version-only --program-suffix=-7 --program-prefix=x86_64-linux-gnu- --enable-shared --enable-linker-build-id --libexecdir=/usr/lib --without-included-gettext --enable-threads=posix --libdir=/usr/lib --enable-nls --enable-bootstrap --enable-clocale=gnu --enable-libstdcxx-debug --enable-libstdcxx-time=yes --with-default-libstdcxx-abi=new --enable-gnu-unique-object --disable-vtable-verify --enable-libmpx --enable-plugin --enable-default-pie --with-system-zlib --with-target-system-zlib --enable-objc-gc=auto --enable-multiarch --disable-werror --with-arch-32=i686 --with-abi=m64 --with-multilib-list=m32,m64,mx32 --enable-multilib --with-tune=generic --enable-offload-targets=nvptx-none --without-cuda-driver --enable-checking=release --build=x86_64-linux-gnu --host=x86_64-linux-gnu --target=x86_64-linux-gnu
# Thread model: posix
# gcc version 7.5.0 (Ubuntu 7.5.0-3ubuntu1~18.04)

# %% [markdown]
# # Install CUDA

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,990 kB]
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,545 kB]
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,155 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,322 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,104 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,422 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [20.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [64.0 kB]
# Fetched 13.9 MB in 3s (4,669 kB/s)
# Reading package lists... Done

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-kernel-common-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-331-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-prebuilt' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-gds' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-396' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-410' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-418' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-455' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-460' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-465' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-470' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-495' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-510' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-515' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-384-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia' for glob 'nvidia*'
# Note, selecting 'nvidia-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-367-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-modprobe' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-texture-tools' for glob 'nvidia*'
# Note, selecting 'nvidia-utils' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-387-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-current-diagnostic' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-349-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-310-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-352-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-prebuilt-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-450' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-455' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-460' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-465' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-470' for glob 'nvidia*'
# Note, selecting 'nvidia-346-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-495' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-510' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-515' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-smi' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-313-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-334-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-410' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-460' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-465' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-470' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-495' for glob 'nvidia*'
# Note, selecting 'nvidia-331-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-510' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-515' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-prime' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-fs' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-410' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-460' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-465' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-470' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-495' for glob 'nvidia*'
# Note, selecting 'nvidia-current-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-340-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-510' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-515' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager' for glob 'nvidia*'
# Note, selecting 'nvidia-nsight' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-common' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-410' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-460' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-465' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-470' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-495' for glob 'nvidia*'
# Note, selecting 'nvidia-current-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-510' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-515' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-410' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-460' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-465' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-470' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-495' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-355-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-libs-nonglvnd' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-510' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-515' for glob 'nvidia*'
# Note, selecting 'nvidia-375-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-current' for glob 'nvidia*'
# Note, selecting 'nvidia-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-375-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-390' for glob 'nvidia*'
# Note, selecting 'nvidia-337-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-358-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-367-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-410' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-430' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-435' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-455' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-460' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-465' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-470' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-495' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-libs' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-510' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-515' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source' for glob 'nvidia*'
# Note, selecting 'nvidia-378-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-319-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-450' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-455' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-460' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-465' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-470' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-495' for glob 'nvidia*'
# Note, selecting 'nvidia-304-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-510' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-515' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-visual-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-persistenced' for glob 'nvidia*'
# Note, selecting 'nvidia-361-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-settings-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-361-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-515' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-304' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-331' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-340' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-352' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-361' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-367' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-375' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-384' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-352-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-340-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-machine-learning-repo-ubuntu1804' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-390' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-410' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-455' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-460' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-465' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-470' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-495' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-510' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-515' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-381-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-304' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-331' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-340' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-346' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-352' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-361' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-367' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-375' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-gdb' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-304' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-384' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-310' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-313' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-319' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-325' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-331' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-334' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-337' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-340' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-343' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-346' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-349' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-352' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-355' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-358' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-361' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-364' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-367' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-375' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-378' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-381' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-384' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-387' for glob 'nvidia*'
# Note, selecting 'nvidia-343-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-364-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-304' for glob 'nvidia*'
# Note, selecting 'nvidia-310' for glob 'nvidia*'
# Note, selecting 'nvidia-313' for glob 'nvidia*'
# Note, selecting 'nvidia-319' for glob 'nvidia*'
# Note, selecting 'nvidia-325' for glob 'nvidia*'
# Note, selecting 'nvidia-331' for glob 'nvidia*'
# Note, selecting 'nvidia-334' for glob 'nvidia*'
# Note, selecting 'nvidia-337' for glob 'nvidia*'
# Note, selecting 'nvidia-340' for glob 'nvidia*'
# Note, selecting 'nvidia-343' for glob 'nvidia*'
# Note, selecting 'nvidia-346' for glob 'nvidia*'
# Note, selecting 'nvidia-349' for glob 'nvidia*'
# Note, selecting 'nvidia-352' for glob 'nvidia*'
# Note, selecting 'nvidia-355' for glob 'nvidia*'
# Note, selecting 'nvidia-358' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-390' for glob 'nvidia*'
# Note, selecting 'nvidia-361' for glob 'nvidia*'
# Note, selecting 'nvidia-364' for glob 'nvidia*'
# Note, selecting 'nvidia-367' for glob 'nvidia*'
# Note, selecting 'nvidia-375' for glob 'nvidia*'
# Note, selecting 'nvidia-378' for glob 'nvidia*'
# Note, selecting 'nvidia-381' for glob 'nvidia*'
# Note, selecting 'nvidia-384' for glob 'nvidia*'
# Note, selecting 'nvidia-387' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-390' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-4' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-5' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-6' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-7' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-410' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-455' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-460' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-465' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-470' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-495' for glob 'nvidia*'
# Note, selecting 'nvidia-settings' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-510' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-515' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd' for glob 'nvidia*'
# Note, selecting 'nvidia-settings' instead of 'nvidia-settings-binary'
# Package 'nvidia-libopencl1-dev' is not installed, so not removed
# Package 'nvidia-libopencl1' is not installed, so not removed
# Package 'nvidia-vdpau-driver' is not installed, so not removed
# Package 'nvidia-legacy-340xx-vdpau-driver' is not installed, so not removed
# Package 'nvidia-390' is not installed, so not removed
# Package 'nvidia-driver' is not installed, so not removed
# Package 'nvidia-legacy-340xx-driver' is not installed, so not removed
# Package 'nvidia-legacy-304xx-driver' is not installed, so not removed
# Package 'nvidia-kernel-dkms' is not installed, so not removed
# Package 'nvidia-legacy-340xx-kernel-dkms' is not installed, so not removed
# Package 'nvidia-legacy-304xx-kernel-dkms' is not installed, so not removed
# Package 'nvidia' is not installed, so not removed
# Package 'nvidia-current-updates' is not installed, so not removed
# Package 'nvidia-experimental-304' is not installed, so not removed
# Package 'nvidia-310' is not installed, so not removed
# Package 'nvidia-310-updates' is not installed, so not removed
# Package 'nvidia-experimental-310' is not installed, so not removed
# Package 'nvidia-313' is not installed, so not removed
# Package 'nvidia-313-updates' is not installed, so not removed
# Package 'nvidia-experimental-313' is not installed, so not removed
# Package 'nvidia-319' is not installed, so not removed
# Package 'nvidia-319-updates' is not installed, so not removed
# Package 'nvidia-experimental-319' is not installed, so not removed
# Package 'nvidia-325' is not installed, so not removed
# Package 'nvidia-325-updates' is not installed, so not removed
# Package 'nvidia-experimental-325' is not installed, so not removed
# Package 'nvidia-experimental-331' is not installed, so not removed
# Package 'nvidia-334' is not installed, so not removed
# Package 'nvidia-334-updates' is not installed, so not removed
# Package 'nvidia-experimental-334' is not installed, so not removed
# Package 'nvidia-337' is not installed, so not removed
# Package 'nvidia-337-updates' is not installed, so not removed
# Package 'nvidia-experimental-337' is not installed, so not removed
# Package 'nvidia-experimental-340' is not installed, so not removed
# Package 'nvidia-343' is not installed, so not removed
# Package 'nvidia-343-updates' is not installed, so not removed
# Package 'nvidia-experimental-343' is not installed, so not removed
# Package 'nvidia-experimental-346' is not installed, so not removed
# Package 'nvidia-349' is not installed, so not removed
# Package 'nvidia-349-updates' is not installed, so not removed
# Package 'nvidia-experimental-349' is not installed, so not removed
# Package 'nvidia-experimental-352' is not installed, so not removed
# Package 'nvidia-355' is not installed, so not removed
# Package 'nvidia-355-updates' is not installed, so not removed
# Package 'nvidia-experimental-355' is not installed, so not removed
# Package 'nvidia-358' is not installed, so not removed
# Package 'nvidia-358-updates' is not installed, so not removed
# Package 'nvidia-experimental-358' is not installed, so not removed
# Package 'nvidia-experimental-361' is not installed, so not removed
# Package 'nvidia-364' is not installed, so not removed
# Package 'nvidia-364-updates' is not installed, so not removed
# Package 'nvidia-experimental-364' is not installed, so not removed
# Package 'nvidia-367-updates' is not installed, so not removed
# Package 'nvidia-experimental-367' is not installed, so not removed
# Package 'nvidia-375-updates' is not installed, so not removed
# Package 'nvidia-experimental-375' is not installed, so not removed
# Package 'nvidia-378' is not installed, so not removed
# Package 'nvidia-378-updates' is not installed, so not removed
# Package 'nvidia-experimental-378' is not installed, so not removed
# Package 'nvidia-381' is not installed, so not removed
# Package 'nvidia-381-updates' is not installed, so not removed
# Package 'nvidia-experimental-381' is not installed, so not removed
# Package 'nvidia-384-updates' is not installed, so not removed
# Package 'nvidia-experimental-384' is not installed, so not removed
# Package 'nvidia-387' is not installed, so not removed
# Package 'nvidia-387-updates' is not installed, so not removed
# Package 'nvidia-experimental-387' is not installed, so not removed
# Note, selecting 'libnvtt-bin' instead of 'nvidia-texture-tools'
# Package 'nvidia-driver-libs' is not installed, so not removed
# Package 'nvidia-driver-libs-nonglvnd' is not installed, so not removed
# Package 'nvidia-fs-prebuilt' is not installed, so not removed
# Package 'nvidia-kernel-common-396' is not installed, so not removed
# Note, selecting 'nvidia-kernel-open-515' instead of 'nvidia-kernel-open'
# Package 'nvidia-legacy-304xx-vdpau-driver' is not installed, so not removed
# Note, selecting 'libnvidia-encode-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ml1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-any' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-470-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-460-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-460' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-465' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-470' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-495' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-515-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-510-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-510' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-515' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-460-server' for glob 'libnvidia-*'
# Package 'nvidia-340-updates-uvm' is not installed, so not removed
# Package 'nvidia-346' is not installed, so not removed
# Package 'nvidia-346-dev' is not installed, so not removed
# Package 'nvidia-346-updates' is not installed, so not removed
# Package 'nvidia-346-updates-dev' is not installed, so not removed
# Package 'nvidia-352' is not installed, so not removed
# Package 'nvidia-352-dev' is not installed, so not removed
# Package 'nvidia-352-updates' is not installed, so not removed
# Package 'nvidia-352-updates-dev' is not installed, so not removed
# Package 'nvidia-361' is not installed, so not removed
# Package 'nvidia-361-dev' is not installed, so not removed
# Package 'nvidia-361-updates' is not installed, so not removed
# Package 'nvidia-361-updates-dev' is not installed, so not removed
# Package 'nvidia-367' is not installed, so not removed
# Package 'nvidia-367-dev' is not installed, so not removed
# Package 'nvidia-375' is not installed, so not removed
# Package 'nvidia-375-dev' is not installed, so not removed
# Package 'nvidia-cg-dev' is not installed, so not removed
# Package 'nvidia-cg-doc' is not installed, so not removed
# Package 'nvidia-cg-toolkit' is not installed, so not removed
# Package 'nvidia-cuda-dev' is not installed, so not removed
# Package 'nvidia-libopencl1-346' is not installed, so not removed
# Package 'nvidia-libopencl1-346-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-352' is not installed, so not removed
# Package 'nvidia-libopencl1-352-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-361' is not installed, so not removed
# Package 'nvidia-libopencl1-361-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-367' is not installed, so not removed
# Package 'nvidia-libopencl1-375' is not installed, so not removed
# Package 'nvidia-nsight' is not installed, so not removed
# Package 'nvidia-opencl-icd-346' is not installed, so not removed
# Package 'nvidia-opencl-icd-346-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-352' is not installed, so not removed
# Package 'nvidia-opencl-icd-352-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-361' is not installed, so not removed
# Package 'nvidia-opencl-icd-361-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-367' is not installed, so not removed
# Package 'nvidia-opencl-icd-375' is not installed, so not removed
# Package 'nvidia-prime' is not installed, so not removed
# Package 'libnvidia-cfg1-390' is not installed, so not removed
# Package 'libnvidia-cfg1-418' is not installed, so not removed
# Package 'libnvidia-cfg1-418-server' is not installed, so not removed
# Package 'libnvidia-cfg1-435' is not installed, so not removed
# Package 'libnvidia-cfg1-440' is not installed, so not removed
# Package 'libnvidia-cfg1-440-server' is not installed, so not removed
# Package 'libnvidia-cfg1-450' is not installed, so not removed
# Package 'libnvidia-cfg1-450-server' is not installed, so not removed
# Package 'libnvidia-cfg1-455' is not installed, so not removed
# Package 'libnvidia-cfg1-460' is not installed, so not removed
# Package 'libnvidia-cfg1-465' is not installed, so not removed
# Package 'libnvidia-cfg1-470-server' is not installed, so not removed
# Package 'libnvidia-cfg1-510-server' is not installed, so not removed
# Package 'libnvidia-cfg1-515-server' is not installed, so not removed
# Package 'libnvidia-common-390' is not installed, so not removed
# Package 'libnvidia-common-418' is not installed, so not removed
# Package 'libnvidia-common-418-server' is not installed, so not removed
# Package 'libnvidia-common-435' is not installed, so not removed
# Package 'libnvidia-common-440' is not installed, so not removed
# Package 'libnvidia-common-440-server' is not installed, so not removed
# Package 'libnvidia-common-450' is not installed, so not removed
# Package 'libnvidia-common-450-server' is not installed, so not removed
# Package 'libnvidia-common-455' is not installed, so not removed
# Package 'libnvidia-common-465' is not installed, so not removed
# Package 'libnvidia-common-470-server' is not installed, so not removed
# Package 'libnvidia-common-510-server' is not installed, so not removed
# Package 'libnvidia-common-515-server' is not installed, so not removed
# Package 'libnvidia-compute-390' is not installed, so not removed
# Package 'libnvidia-compute-418' is not installed, so not removed
# Package 'libnvidia-compute-418-server' is not installed, so not removed
# Package 'libnvidia-compute-435' is not installed, so not removed
# Package 'libnvidia-compute-440' is not installed, so not removed
# Package 'libnvidia-compute-440-server' is not installed, so not removed
# Package 'libnvidia-compute-450' is not installed, so not removed
# Package 'libnvidia-compute-450-server' is not installed, so not removed
# Package 'libnvidia-compute-455' is not installed, so not removed
# Package 'libnvidia-compute-465' is not installed, so not removed
# Package 'libnvidia-compute-470-server' is not installed, so not removed
# Package 'libnvidia-compute-510-server' is not installed, so not removed
# Package 'libnvidia-compute-515-server' is not installed, so not removed
# Package 'libnvidia-decode-390' is not installed, so not removed
# Package 'libnvidia-decode-418' is not installed, so not removed
# Package 'libnvidia-decode-418-server' is not installed, so not removed
# Package 'libnvidia-decode-435' is not installed, so not removed
# Package 'libnvidia-decode-440' is not installed, so not removed
# Package 'libnvidia-decode-440-server' is not installed, so not removed
# Package 'libnvidia-decode-450' is not installed, so not removed
# Package 'libnvidia-decode-450-server' is not installed, so not removed
# Package 'libnvidia-decode-455' is not installed, so not removed
# Package 'libnvidia-decode-460' is not installed, so not removed
# Package 'libnvidia-decode-465' is not installed, so not removed
# Package 'libnvidia-decode-470-server' is not installed, so not removed
# Package 'libnvidia-decode-510-server' is not installed, so not removed
# Package 'libnvidia-decode-515-server' is not installed, so not removed
# Package 'libnvidia-encode-390' is not installed, so not removed
# Package 'libnvidia-encode-418' is not installed, so not removed
# Package 'libnvidia-encode-418-server' is not installed, so not removed
# Package 'libnvidia-encode-435' is not installed, so not removed
# Package 'libnvidia-encode-440' is not installed, so not removed
# Package 'libnvidia-encode-440-server' is not installed, so not removed
# Package 'libnvidia-encode-450' is not installed, so not removed
# Package 'libnvidia-encode-450-server' is not installed, so not removed
# Package 'libnvidia-encode-455' is not installed, so not removed
# Package 'libnvidia-encode-460' is not installed, so not removed
# Package 'libnvidia-encode-465' is not installed, so not removed
# Package 'libnvidia-encode-470-server' is not installed, so not removed
# Package 'libnvidia-encode-510-server' is not installed, so not removed
# Package 'libnvidia-encode-515-server' is not installed, so not removed
# Package 'libnvidia-extra-440' is not installed, so not removed
# Package 'libnvidia-extra-440-server' is not installed, so not removed
# Package 'libnvidia-extra-450' is not installed, so not removed
# Package 'libnvidia-extra-450-server' is not installed, so not removed
# Package 'libnvidia-extra-455' is not installed, so not removed
# Package 'libnvidia-extra-460' is not installed, so not removed
# Package 'libnvidia-extra-465' is not installed, so not removed
# Package 'libnvidia-extra-470-server' is not installed, so not removed
# Package 'libnvidia-extra-510-server' is not installed, so not removed
# Package 'libnvidia-extra-515-server' is not installed, so not removed
# Package 'libnvidia-fbc1-390' is not installed, so not removed
# Package 'libnvidia-fbc1-418' is not installed, so not removed
# Package 'libnvidia-fbc1-418-server' is not installed, so not removed
# Package 'libnvidia-fbc1-435' is not installed, so not removed
# Package 'libnvidia-fbc1-440' is not installed, so not removed
# Package 'libnvidia-fbc1-440-server' is not installed, so not removed
# Package 'libnvidia-fbc1-450' is not installed, so not removed
# Package 'libnvidia-fbc1-450-server' is not installed, so not removed
# Package 'libnvidia-fbc1-455' is not installed, so not removed
# Package 'libnvidia-fbc1-460' is not installed, so not removed
# Package 'libnvidia-fbc1-465' is not installed, so not removed
# Package 'libnvidia-fbc1-470-server' is not installed, so not removed
# Package 'libnvidia-fbc1-510-server' is not installed, so not removed
# Package 'libnvidia-fbc1-515-server' is not installed, so not removed
# Package 'libnvidia-gl-390' is not installed, so not removed
# Package 'libnvidia-gl-418' is not installed, so not removed
# Package 'libnvidia-gl-418-server' is not installed, so not removed
# Package 'libnvidia-gl-435' is not installed, so not removed
# Package 'libnvidia-gl-440' is not installed, so not removed
# Package 'libnvidia-gl-440-server' is not installed, so not removed
# Package 'libnvidia-gl-450' is not installed, so not removed
# Package 'libnvidia-gl-450-server' is not installed, so not removed
# Package 'libnvidia-gl-455' is not installed, so not removed
# ...
# Package 'nvidia-headless-no-dkms-418-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-435' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-440' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-440-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-450' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-450-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-455' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-460' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-465' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-470-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-510-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-515-server' is not installed, so not removed
# Package 'nvidia-kernel-common-390' is not installed, so not removed
# Package 'nvidia-kernel-common-418' is not installed, so not removed
# Package 'nvidia-kernel-common-418-server' is not installed, so not removed
# Package 'nvidia-kernel-common-435' is not installed, so not removed
# Package 'nvidia-kernel-common-440' is not installed, so not removed
# Package 'nvidia-kernel-common-440-server' is not installed, so not removed
# Package 'nvidia-kernel-common-450' is not installed, so not removed
# Package 'nvidia-kernel-common-450-server' is not installed, so not removed
# Package 'nvidia-kernel-common-455' is not installed, so not removed
# Package 'nvidia-kernel-common-460' is not installed, so not removed
# Package 'nvidia-kernel-common-465' is not installed, so not removed
# Package 'nvidia-kernel-common-470-server' is not installed, so not removed
# Package 'nvidia-kernel-common-510-server' is not installed, so not removed
# Package 'nvidia-kernel-common-515-server' is not installed, so not removed
# Package 'nvidia-kernel-source-390' is not installed, so not removed
# Package 'nvidia-kernel-source-418' is not installed, so not removed
# Package 'nvidia-kernel-source-418-server' is not installed, so not removed
# Package 'nvidia-kernel-source-435' is not installed, so not removed
# Package 'nvidia-kernel-source-440' is not installed, so not removed
# Package 'nvidia-kernel-source-440-server' is not installed, so not removed
# Package 'nvidia-kernel-source-450' is not installed, so not removed
# Package 'nvidia-kernel-source-450-server' is not installed, so not removed
# Package 'nvidia-kernel-source-455' is not installed, so not removed
# Package 'nvidia-kernel-source-460' is not installed, so not removed
# Package 'nvidia-kernel-source-465' is not installed, so not removed
# Package 'nvidia-kernel-source-470-server' is not installed, so not removed
# Package 'nvidia-kernel-source-510-server' is not installed, so not removed
# Package 'nvidia-kernel-source-515-server' is not installed, so not removed
# Package 'nvidia-opencl-icd-340' is not installed, so not removed
# Package 'nvidia-utils-390' is not installed, so not removed
# Package 'nvidia-utils-418' is not installed, so not removed
# Package 'nvidia-utils-418-server' is not installed, so not removed
# Package 'nvidia-utils-435' is not installed, so not removed
# Package 'nvidia-utils-440' is not installed, so not removed
# Package 'nvidia-utils-440-server' is not installed, so not removed
# Package 'nvidia-utils-450' is not installed, so not removed
# Package 'nvidia-utils-450-server' is not installed, so not removed
# Package 'nvidia-utils-455' is not installed, so not removed
# Package 'nvidia-utils-460' is not installed, so not removed
# Package 'nvidia-utils-465' is not installed, so not removed
# Package 'nvidia-utils-470-server' is not installed, so not removed
# Package 'nvidia-utils-510-server' is not installed, so not removed
# Package 'nvidia-utils-515-server' is not installed, so not removed
# Package 'nvidia-common' is not installed, so not removed
# Package 'libnvidia-cfg1-460-server' is not installed, so not removed
# Package 'libnvidia-common-460-server' is not installed, so not removed
# Package 'libnvidia-compute-460-server' is not installed, so not removed
# Package 'libnvidia-decode-460-server' is not installed, so not removed
# Package 'libnvidia-encode-460-server' is not installed, so not removed
# Package 'libnvidia-extra-460-server' is not installed, so not removed
# Package 'libnvidia-fbc1-460-server' is not installed, so not removed
# Package 'libnvidia-gl-460-server' is not installed, so not removed
# Package 'libnvidia-ifr1-460-server' is not installed, so not removed
# Package 'libnvidia-nscq-460' is not installed, so not removed
# Package 'nvidia-compute-utils-460-server' is not installed, so not removed
# Package 'nvidia-dkms-460-server' is not installed, so not removed
# Package 'nvidia-driver-460-server' is not installed, so not removed
# Package 'nvidia-fabricmanager-460' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-460' is not installed, so not removed
# Package 'nvidia-headless-460-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-460-server' is not installed, so not removed
# Package 'nvidia-kernel-common-460-server' is not installed, so not removed
# Package 'nvidia-kernel-source-460-server' is not installed, so not removed
# Package 'nvidia-libopencl1-331' is not installed, so not removed
# Package 'nvidia-libopencl1-331-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-340' is not installed, so not removed
# Package 'nvidia-libopencl1-340-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-331' is not installed, so not removed
# Package 'nvidia-opencl-icd-331-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-340-updates' is not installed, so not removed
# Package 'nvidia-utils-460-server' is not installed, so not removed
# Package 'nvidia-machine-learning-repo-ubuntu1804' is not installed, so not removed
# Package 'libnvidia-cfg1-410' is not installed, so not removed
# Package 'libnvidia-common-410' is not installed, so not removed
# Package 'libnvidia-compute-410' is not installed, so not removed
# Package 'libnvidia-decode-410' is not installed, so not removed
# Package 'libnvidia-diagnostic-410' is not installed, so not removed
# Package 'libnvidia-diagnostic-418' is not installed, so not removed
# Package 'libnvidia-encode-410' is not installed, so not removed
# Package 'libnvidia-fbc1-410' is not installed, so not removed
# Package 'libnvidia-gl-410' is not installed, so not removed
# Package 'libnvidia-ifr1-410' is not installed, so not removed
# Package 'nvidia-384' is not installed, so not removed
# Package 'nvidia-384-dev' is not installed, so not removed
# Package 'nvidia-compute-utils-410' is not installed, so not removed
# Package 'nvidia-dkms-410' is not installed, so not removed
# Package 'nvidia-driver-410' is not installed, so not removed
# Package 'nvidia-gds-11-4' is not installed, so not removed
# Package 'nvidia-gds-11-5' is not installed, so not removed
# Package 'nvidia-gds-11-6' is not installed, so not removed
# Package 'nvidia-headless-410' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-410' is not installed, so not removed
# Package 'nvidia-kernel-common-410' is not installed, so not removed
# Package 'nvidia-kernel-source-410' is not installed, so not removed
# Package 'nvidia-libopencl1-384' is not installed, so not removed
# Package 'nvidia-opencl-icd-384' is not installed, so not removed
# Package 'nvidia-utils-410' is not installed, so not removed
# Package 'libnvidia-nscq-455' is not installed, so not removed
# Package 'libnvidia-nscq-465' is not installed, so not removed
# Package 'libnvidia-nscq-495' is not installed, so not removed
# Package 'nvidia-fabricmanager-455' is not installed, so not removed
# Package 'nvidia-fabricmanager-465' is not installed, so not removed
# Package 'nvidia-fabricmanager-495' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-455' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-465' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-495' is not installed, so not removed
# Package 'libnvidia-cfg1-430' is not installed, so not removed
# Package 'libnvidia-cfg1-470' is not installed, so not removed
# Package 'libnvidia-common-430' is not installed, so not removed
# Package 'libnvidia-common-470' is not installed, so not removed
# Package 'libnvidia-compute-430' is not installed, so not removed
# Package 'libnvidia-compute-470' is not installed, so not removed
# Package 'libnvidia-decode-430' is not installed, so not removed
# Package 'libnvidia-decode-470' is not installed, so not removed
# Package 'libnvidia-encode-430' is not installed, so not removed
# Package 'libnvidia-encode-470' is not installed, so not removed
# Package 'libnvidia-extra-470' is not installed, so not removed
# Package 'libnvidia-fbc1-430' is not installed, so not removed
# Package 'libnvidia-fbc1-470' is not installed, so not removed
# Package 'libnvidia-gl-430' is not installed, so not removed
# Package 'libnvidia-gl-470' is not installed, so not removed
# Package 'libnvidia-ifr1-430' is not installed, so not removed
# Package 'libnvidia-ifr1-470' is not installed, so not removed
# Package 'libnvidia-nscq-450' is not installed, so not removed
# Package 'libnvidia-nscq-470' is not installed, so not removed
# Package 'libnvidia-nscq-515' is not installed, so not removed
# Package 'nvidia-compute-utils-430' is not installed, so not removed
# Package 'nvidia-compute-utils-470' is not installed, so not removed
# Package 'nvidia-dkms-430' is not installed, so not removed
# Package 'nvidia-dkms-470' is not installed, so not removed
# Package 'nvidia-driver-430' is not installed, so not removed
# Package 'nvidia-driver-470' is not installed, so not removed
# Package 'nvidia-fabricmanager-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-470' is not installed, so not removed
# Package 'nvidia-fabricmanager-515' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-470' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-515' is not installed, so not removed
# Package 'nvidia-headless-430' is not installed, so not removed
# Package 'nvidia-headless-470' is not installed, so not removed
# Package 'nvidia-headless-515' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-430' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-470' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-515' is not installed, so not removed
# Package 'nvidia-kernel-common-430' is not installed, so not removed
# Package 'nvidia-kernel-common-470' is not installed, so not removed
# Package 'nvidia-kernel-open-515' is not installed, so not removed
# Package 'nvidia-kernel-source-430' is not installed, so not removed
# Package 'nvidia-kernel-source-470' is not installed, so not removed
# Package 'nvidia-utils-430' is not installed, so not removed
# Package 'nvidia-utils-470' is not installed, so not removed
# Package 'libnvidia-cfg1-510' is not installed, so not removed
# Package 'libnvidia-common-510' is not installed, so not removed
# Package 'libnvidia-compute-510' is not installed, so not removed
# Package 'libnvidia-decode-510' is not installed, so not removed
# Package 'libnvidia-encode-510' is not installed, so not removed
# Package 'libnvidia-extra-510' is not installed, so not removed
# Package 'libnvidia-fbc1-510' is not installed, so not removed
# Package 'libnvidia-gl-510' is not installed, so not removed
# Package 'libnvidia-nscq-510' is not installed, so not removed
# Package 'nvidia-compute-utils-510' is not installed, so not removed
# Package 'nvidia-dkms-510' is not installed, so not removed
# Package 'nvidia-driver-510' is not installed, so not removed
# Package 'nvidia-fabricmanager-510' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-510' is not installed, so not removed
# Package 'nvidia-headless-510' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-510' is not installed, so not removed
# Package 'nvidia-kernel-common-510' is not installed, so not removed
# Package 'nvidia-kernel-source-510' is not installed, so not removed
# Package 'nvidia-utils-510' is not installed, so not removed
# Package 'nvidia-fs' is not installed, so not removed
# Package 'nvidia-fs-dkms' is not installed, so not removed
# Package 'nvidia-gds-11-7' is not installed, so not removed
# Package 'nvidia-gds' is not installed, so not removed
# Package 'libnvidia-cfg1-495' is not installed, so not removed
# Package 'libnvidia-common-495' is not installed, so not removed
# Package 'libnvidia-compute-495' is not installed, so not removed
# Package 'libnvidia-decode-495' is not installed, so not removed
# Package 'libnvidia-encode-495' is not installed, so not removed
# Package 'libnvidia-extra-495' is not installed, so not removed
# Package 'libnvidia-fbc1-495' is not installed, so not removed
# Package 'libnvidia-gl-495' is not installed, so not removed
# Package 'nvidia-304' is not installed, so not removed
# Package 'nvidia-304-dev' is not installed, so not removed
# Package 'nvidia-304-updates' is not installed, so not removed
# Package 'nvidia-304-updates-dev' is not installed, so not removed
# Package 'nvidia-compute-utils-495' is not installed, so not removed
# Package 'nvidia-current' is not installed, so not removed
# Package 'nvidia-current-dev' is not installed, so not removed
# Package 'nvidia-dkms-495' is not installed, so not removed
# Package 'nvidia-driver-495' is not installed, so not removed
# Package 'nvidia-headless-495' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-495' is not installed, so not removed
# Package 'nvidia-kernel-common-495' is not installed, so not removed
# Package 'nvidia-kernel-source-495' is not installed, so not removed
# Package 'nvidia-libopencl1-304' is not installed, so not removed
# Package 'nvidia-libopencl1-304-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-304' is not installed, so not removed
# Package 'nvidia-opencl-icd-304-updates' is not installed, so not removed
# Package 'nvidia-utils-495' is not installed, so not removed
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  cuda-drivers-515 : Depends: libnvidia-common-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: libnvidia-compute-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: libnvidia-decode-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: libnvidia-encode-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: libnvidia-fbc1-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: libnvidia-gl-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-compute-utils-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-dkms-515 (>= 515.65.01)
#                     Depends: nvidia-driver-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-kernel-common-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-kernel-source-515 (>= 515.65.01) but it is not going to be installed or
#                              nvidia-kernel-open-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-utils-515 (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-modprobe (>= 515.65.01) but it is not going to be installed
#                     Depends: nvidia-settings (>= 515.65.01) but it is not going to be installed
#  libcuinj64-9.1 : Depends: libcuda1 (>= 387.26) or
#                            libcuda-9.1-1
#  xserver-xorg-video-nvidia-515 : Depends: libnvidia-cfg1-515 (= 515.65.01-0ubuntu1) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# Out:
# (Reading database ... 167197 files and directories currently installed.)
# Removing cuda-10-0 (10.0.130-1) ...
# (Reading database ... 167194 files and directories currently installed.)
# Removing cuda-10-1 (10.1.243-1) ...
# (Reading database ... 167191 files and directories currently installed.)
# Removing cuda-11-0 (11.0.3-1) ...
# (Reading database ... 167189 files and directories currently installed.)
# Removing cuda-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-11-7:
#  cuda depends on cuda-11-7 (>= 11.7.1).
#
# dpkg: error processing package cuda-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-11-7
# dpkg: dependency problems prevent removal of cuda-cccl-11-7:
#  cuda-cudart-dev-11-7 depends on cuda-cccl-11-7; however:
#   Package cuda-cccl-11-7 is to be removed.
#  cuda-libraries-dev-11-7 depends on cuda-cccl-11-7 (>= 11.7.91); however:
#   Package cuda-cccl-11-7 is to be removed.
#
# dpkg: error processing package cuda-cccl-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cccl-11-7
# dpkg: dependency problems prevent removal of cuda-command-line-tools-10-0:
#  cuda-tools-10-0 depends on cuda-command-line-tools-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-command-line-tools-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-command-line-tools-10-0
# dpkg: dependency problems prevent removal of cuda-command-line-tools-10-1:
#  cuda-tools-10-1 depends on cuda-command-line-tools-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-command-line-tools-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-command-line-tools-10-1
# dpkg: dependency problems prevent removal of cuda-command-line-tools-11-0:
#  cuda-tools-11-0 depends on cuda-command-line-tools-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-command-line-tools-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-command-line-tools-11-0
# dpkg: dependency problems prevent removal of cuda-command-line-tools-11-1:
#  cuda-tools-11-1 depends on cuda-command-line-tools-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-command-line-tools-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-command-line-tools-11-1
# dpkg: dependency problems prevent removal of cuda-command-line-tools-11-7:
#  cuda-tools-11-7 depends on cuda-command-line-tools-11-7 (>= 11.7.1).
#
# dpkg: error processing package cuda-command-line-tools-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-command-line-tools-11-7
# (Reading database ... 167187 files and directories currently installed.)
# Removing cuda-compat-11-1 (455.45.01-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# dpkg: dependency problems prevent removal of cuda-compiler-10-0:
#  cuda-toolkit-10-0 depends on cuda-compiler-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-compiler-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-compiler-10-0
# dpkg: dependency problems prevent removal of cuda-compiler-10-1:
#  cuda-toolkit-10-1 depends on cuda-compiler-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-compiler-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-compiler-10-1
# dpkg: dependency problems prevent removal of cuda-compiler-11-0:
#  cuda-toolkit-11-0 depends on cuda-compiler-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-compiler-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-compiler-11-0
# dpkg: dependency problems prevent removal of cuda-compiler-11-1:
#  cuda-toolkit-11-1 depends on cuda-compiler-11-1 (>= 11.1.1).
#  cuda-minimal-build-11-1 depends on cuda-compiler-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-compiler-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-compiler-11-1
# dpkg: dependency problems prevent removal of cuda-compiler-11-7:
#  cuda-toolkit-11-7 depends on cuda-compiler-11-7 (>= 11.7.1).
#
# dpkg: error processing package cuda-compiler-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-compiler-11-7
# dpkg: dependency problems prevent removal of cuda-cublas-10-0:
#  cuda-libraries-10-0 depends on cuda-cublas-10-0 (>= 10.0.130).
#  cuda-cublas-dev-10-0 depends on cuda-cublas-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cublas-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cublas-10-0
# dpkg: dependency problems prevent removal of cuda-cublas-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-cublas-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-cublas-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-cublas-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cublas-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cublas-dev-10-0
# dpkg: dependency problems prevent removal of cuda-cudart-10-0:
#  cuda-cudart-dev-10-0 depends on cuda-cudart-10-0 (>= 10.0.130).
#  cuda-libraries-10-0 depends on cuda-cudart-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cudart-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-10-0
# dpkg: dependency problems prevent removal of cuda-cudart-10-1:
#  cuda-cudart-dev-10-1 depends on cuda-cudart-10-1 (>= 10.1.243).
#  cuda-libraries-10-1 depends on cuda-cudart-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cudart-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-10-1
# dpkg: dependency problems prevent removal of cuda-cudart-11-0:
#  cuda-libraries-11-0 depends on cuda-cudart-11-0 (>= 11.0.221).
#  cuda-cudart-dev-11-0 depends on cuda-cudart-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-cudart-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-11-0
# dpkg: dependency problems prevent removal of cuda-cudart-11-1:
#  cuda-libraries-11-1 depends on cuda-cudart-11-1 (>= 11.1.74).
#  cuda-cudart-dev-11-1 depends on cuda-cudart-11-1 (>= 11.1.74).
#
# dpkg: error processing package cuda-cudart-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-11-1
# dpkg: dependency problems prevent removal of cuda-cudart-11-7:
#  cuda-cudart-dev-11-7 depends on cuda-cudart-11-7 (>= 11.7.99).
#  cuda-libraries-11-7 depends on cuda-cudart-11-7 (>= 11.7.99).
#
# dpkg: error processing package cuda-cudart-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-11-7
# dpkg: dependency problems prevent removal of cuda-cudart-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-cudart-dev-10-0 (>= 10.0.130).
#  cuda-cupti-10-0 depends on cuda-cudart-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-cudart-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-cudart-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cudart-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-dev-10-0
# dpkg: dependency problems prevent removal of cuda-cudart-dev-10-1:
#  cuda-samples-10-1 depends on cuda-cudart-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-cudart-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-cudart-dev-10-1 (>= 10.1.243).
#  cuda-cupti-10-1 depends on cuda-cudart-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cudart-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-dev-10-1
# dpkg: dependency problems prevent removal of cuda-cudart-dev-11-0:
#  cuda-cupti-11-0 depends on cuda-cudart-dev-11-0.
#  cuda-visual-tools-11-0 depends on cuda-cudart-dev-11-0 (>= 11.0.221).
#  cuda-samples-11-0 depends on cuda-cudart-dev-11-0.
#  cuda-nvcc-11-0 depends on cuda-cudart-dev-11-0.
#  cuda-libraries-dev-11-0 depends on cuda-cudart-dev-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-cudart-dev-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-dev-11-0
# dpkg: dependency problems prevent removal of cuda-cudart-dev-11-1:
#  cuda-nvcc-11-1 depends on cuda-cudart-dev-11-1.
#  cuda-samples-11-1 depends on cuda-cudart-dev-11-1.
#  cuda-visual-tools-11-1 depends on cuda-cudart-dev-11-1 (>= 11.1.74).
#  cuda-libraries-dev-11-1 depends on cuda-cudart-dev-11-1 (>= 11.1.74).
#  cuda-minimal-build-11-1 depends on cuda-cudart-dev-11-1 (>= 11.1.74).
#  cuda-cupti-11-1 depends on cuda-cudart-dev-11-1.
#
# dpkg: error processing package cuda-cudart-dev-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-dev-11-1
# dpkg: dependency problems prevent removal of cuda-cudart-dev-11-7:
#  cuda-nvcc-11-7 depends on cuda-cudart-dev-11-7.
#  cuda-libraries-dev-11-7 depends on cuda-cudart-dev-11-7 (>= 11.7.99).
#  cuda-cupti-11-7 depends on cuda-cudart-dev-11-7.
#
# dpkg: error processing package cuda-cudart-dev-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cudart-dev-11-7
# dpkg: dependency problems prevent removal of cuda-cufft-10-0:
#  cuda-libraries-10-0 depends on cuda-cufft-10-0 (>= 10.0.130).
#  cuda-cufft-dev-10-0 depends on cuda-cufft-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cufft-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cufft-10-0
# dpkg: dependency problems prevent removal of cuda-cufft-10-1:
#  cuda-cufft-dev-10-1 depends on cuda-cufft-10-1 (>= 10.1.243).
#  cuda-libraries-10-1 depends on cuda-cufft-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cufft-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cufft-10-1
# dpkg: dependency problems prevent removal of cuda-cufft-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-cufft-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-cufft-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-cufft-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cufft-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cufft-dev-10-0
# dpkg: dependency problems prevent removal of cuda-cufft-dev-10-1:
#  cuda-samples-10-1 depends on cuda-cufft-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-cufft-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-cufft-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cufft-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cufft-dev-10-1
# dpkg: dependency problems prevent removal of cuda-cuobjdump-10-0:
#  cuda-compiler-10-0 depends on cuda-cuobjdump-10-0 (>= 10.0.130).
#  cuda-gdb-10-0 depends on cuda-cuobjdump-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cuobjdump-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuobjdump-10-0
# dpkg: dependency problems prevent removal of cuda-cuobjdump-10-1:
#  cuda-gdb-10-1 depends on cuda-cuobjdump-10-1 (>= 10.1.243).
#  cuda-compiler-10-1 depends on cuda-cuobjdump-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cuobjdump-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuobjdump-10-1
# dpkg: dependency problems prevent removal of cuda-cuobjdump-11-0:
#  cuda-compiler-11-0 depends on cuda-cuobjdump-11-0 (>= 11.0.221).
#  cuda-gdb-11-0 depends on cuda-cuobjdump-11-0.
#
# dpkg: error processing package cuda-cuobjdump-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuobjdump-11-0
# dpkg: dependency problems prevent removal of cuda-cuobjdump-11-1:
#  cuda-gdb-11-1 depends on cuda-cuobjdump-11-1.
#  cuda-compiler-11-1 depends on cuda-cuobjdump-11-1 (>= 11.1.74).
#
# dpkg: error processing package cuda-cuobjdump-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuobjdump-11-1
# dpkg: dependency problems prevent removal of cuda-cuobjdump-11-7:
#  cuda-gdb-11-7 depends on cuda-cuobjdump-11-7; however:
#   Package cuda-cuobjdump-11-7 is to be removed.
#  cuda-compiler-11-7 depends on cuda-cuobjdump-11-7 (>= 11.7.91).
#
# dpkg: error processing package cuda-cuobjdump-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuobjdump-11-7
# dpkg: dependency problems prevent removal of cuda-cupti-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-cupti-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cupti-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-10-0
# dpkg: dependency problems prevent removal of cuda-cupti-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-cupti-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cupti-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-10-1
# dpkg: dependency problems prevent removal of cuda-cupti-11-0:
#  cuda-cupti-dev-11-0 depends on cuda-cupti-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-cupti-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-11-0
# dpkg: dependency problems prevent removal of cuda-cupti-11-1:
#  cuda-cupti-dev-11-1 depends on cuda-cupti-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-cupti-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-11-1
# dpkg: dependency problems prevent removal of cuda-cupti-11-7:
#  cuda-cupti-dev-11-7 depends on cuda-cupti-11-7 (>= 11.7.101).
#
# dpkg: error processing package cuda-cupti-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-11-7
# dpkg: dependency problems prevent removal of cuda-cupti-dev-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-cupti-dev-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-cupti-dev-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-dev-11-0
# dpkg: dependency problems prevent removal of cuda-cupti-dev-11-1:
#  cuda-command-line-tools-11-1 depends on cuda-cupti-dev-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-cupti-dev-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-dev-11-1
# dpkg: dependency problems prevent removal of cuda-cupti-dev-11-7:
#  cuda-command-line-tools-11-7 depends on cuda-cupti-dev-11-7 (>= 11.7.101).
#
# dpkg: error processing package cuda-cupti-dev-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cupti-dev-11-7
# dpkg: dependency problems prevent removal of cuda-curand-10-0:
#  cuda-curand-dev-10-0 depends on cuda-curand-10-0 (>= 10.0.130).
#  cuda-libraries-10-0 depends on cuda-curand-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-curand-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-curand-10-0
# dpkg: dependency problems prevent removal of cuda-curand-10-1:
#  cuda-curand-dev-10-1 depends on cuda-curand-10-1 (>= 10.1.243).
#  cuda-libraries-10-1 depends on cuda-curand-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-curand-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-curand-10-1
# dpkg: dependency problems prevent removal of cuda-curand-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-curand-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-curand-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-curand-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-curand-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-curand-dev-10-0
# dpkg: dependency problems prevent removal of cuda-curand-dev-10-1:
#  cuda-samples-10-1 depends on cuda-curand-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-curand-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-curand-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-curand-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-curand-dev-10-1
# dpkg: dependency problems prevent removal of cuda-cusolver-10-0:
#  cuda-cusolver-dev-10-0 depends on cuda-cusolver-10-0 (>= 10.0.130).
#  cuda-libraries-10-0 depends on cuda-cusolver-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cusolver-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusolver-10-0
# dpkg: dependency problems prevent removal of cuda-cusolver-10-1:
#  cuda-cusolver-dev-10-1 depends on cuda-cusolver-10-1 (>= 10.1.243).
#  cuda-libraries-10-1 depends on cuda-cusolver-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cusolver-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusolver-10-1
# dpkg: dependency problems prevent removal of cuda-cusolver-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-cusolver-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-cusolver-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-cusolver-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cusolver-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusolver-dev-10-0
# dpkg: dependency problems prevent removal of cuda-cusolver-dev-10-1:
#  cuda-samples-10-1 depends on cuda-cusolver-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-cusolver-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-cusolver-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cusolver-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusolver-dev-10-1
# dpkg: dependency problems prevent removal of cuda-cusparse-10-0:
#  cuda-cusparse-dev-10-0 depends on cuda-cusparse-10-0 (>= 10.0.130).
#  cuda-libraries-10-0 depends on cuda-cusparse-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cusparse-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusparse-10-0
# dpkg: dependency problems prevent removal of cuda-cusparse-10-1:
#  cuda-cusparse-dev-10-1 depends on cuda-cusparse-10-1 (>= 10.1.243).
#  cuda-libraries-10-1 depends on cuda-cusparse-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cusparse-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusparse-10-1
# dpkg: dependency problems prevent removal of cuda-cusparse-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-cusparse-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-cusparse-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-cusparse-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-cusparse-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusparse-dev-10-0
# dpkg: dependency problems prevent removal of cuda-cusparse-dev-10-1:
#  cuda-samples-10-1 depends on cuda-cusparse-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-cusparse-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-cusparse-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-cusparse-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cusparse-dev-10-1
# dpkg: dependency problems prevent removal of cuda-cuxxfilt-11-7:
#  cuda-compiler-11-7 depends on cuda-cuxxfilt-11-7 (>= 11.7.91); however:
#   Package cuda-cuxxfilt-11-7 is to be removed.
#
# dpkg: error processing package cuda-cuxxfilt-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-cuxxfilt-11-7
# (Reading database ... 167179 files and directories currently installed.)
# Removing cuda-demo-suite-10-0 (10.0.130-1) ...
# (Reading database ... 167159 files and directories currently installed.)
# Removing cuda-demo-suite-10-1 (10.1.243-1) ...
# (Reading database ... 167139 files and directories currently installed.)
# Removing cuda-demo-suite-11-0 (11.0.167-1) ...
# (Reading database ... 167119 files and directories currently installed.)
# Removing cuda-demo-suite-11-1 (11.1.74-1) ...
# dpkg: dependency problems prevent removal of cuda-demo-suite-11-7:
#  cuda-11-7 depends on cuda-demo-suite-11-7 (>= 11.7.91); however:
#   Package cuda-demo-suite-11-7 is to be removed.
#
# dpkg: error processing package cuda-demo-suite-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-demo-suite-11-7
# dpkg: dependency problems prevent removal of cuda-documentation-10-0:
#  cuda-toolkit-10-0 depends on cuda-documentation-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-documentation-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-documentation-10-0
# dpkg: dependency problems prevent removal of cuda-documentation-10-1:
#  cuda-toolkit-10-1 depends on cuda-documentation-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-documentation-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-documentation-10-1
# dpkg: dependency problems prevent removal of cuda-documentation-11-0:
#  cuda-toolkit-11-0 depends on cuda-documentation-11-0 (>= 11.0.228).
#
# dpkg: error processing package cuda-documentation-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-documentation-11-0
# dpkg: dependency problems prevent removal of cuda-documentation-11-1:
#  cuda-toolkit-11-1 depends on cuda-documentation-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-documentation-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-documentation-11-1
# dpkg: dependency problems prevent removal of cuda-documentation-11-7:
#  cuda-toolkit-11-7 depends on cuda-documentation-11-7 (>= 11.7.91); however:
#   Package cuda-documentation-11-7 is to be removed.
#
# dpkg: error processing package cuda-documentation-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-documentation-11-7
# dpkg: dependency problems prevent removal of cuda-driver-dev-10-0:
#  cuda-cudart-dev-10-0 depends on cuda-driver-dev-10-0 (>= 10.0.130).
#  cuda-visual-tools-10-0 depends on cuda-driver-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-driver-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-driver-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-driver-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-driver-dev-10-0
# dpkg: dependency problems prevent removal of cuda-driver-dev-10-1:
#  cuda-samples-10-1 depends on cuda-driver-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-driver-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-driver-dev-10-1 (>= 10.1.243).
#  cuda-cudart-dev-10-1 depends on cuda-driver-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-driver-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-driver-dev-10-1
# dpkg: dependency problems prevent removal of cuda-driver-dev-11-0:
#  cuda-visual-tools-11-0 depends on cuda-driver-dev-11-0 (>= 11.0.221).
#  cuda-samples-11-0 depends on cuda-driver-dev-11-0.
#  cuda-cudart-dev-11-0 depends on cuda-driver-dev-11-0 (>= 11.0.221).
#  cuda-libraries-dev-11-0 depends on cuda-driver-dev-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-driver-dev-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-driver-dev-11-0
# dpkg: dependency problems prevent removal of cuda-driver-dev-11-1:
#  cuda-samples-11-1 depends on cuda-driver-dev-11-1.
#  cuda-cudart-dev-11-1 depends on cuda-driver-dev-11-1 (>= 11.1.74).
#  cuda-visual-tools-11-1 depends on cuda-driver-dev-11-1 (>= 11.1.74).
#  cuda-libraries-dev-11-1 depends on cuda-driver-dev-11-1 (>= 11.1.74).
#
# dpkg: error processing package cuda-driver-dev-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-driver-dev-11-1
# dpkg: dependency problems prevent removal of cuda-driver-dev-11-7:
#  cuda-cudart-dev-11-7 depends on cuda-driver-dev-11-7 (>= 11.7.99); however:
#   Package cuda-driver-dev-11-7 is to be removed.
#  cuda-libraries-dev-11-7 depends on cuda-driver-dev-11-7 (>= 11.7.99); however:
#   Package cuda-driver-dev-11-7 is to be removed.
#
# dpkg: error processing package cuda-driver-dev-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-driver-dev-11-7
# dpkg: dependency problems prevent removal of cuda-drivers:
#  cuda-runtime-11-7 depends on cuda-drivers (>= 515.65.01); however:
#   Package cuda-drivers is to be removed.
#  cuda-runtime-11-0 depends on cuda-drivers (>= 450.51.06).
#  cuda-runtime-10-1 depends on cuda-drivers (>= 418.87).
#  cuda-runtime-11-1 depends on cuda-drivers (>= 455.32.00).
#  cuda-runtime-10-0 depends on cuda-drivers (>= 410.48).
#
# dpkg: error processing package cuda-drivers (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-drivers
# dpkg: dependency problems prevent removal of cuda-drivers-515:
#  cuda-drivers depends on cuda-drivers-515 (= 515.65.01-1).
#
# dpkg: error processing package cuda-drivers-515 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-drivers-515
# dpkg: dependency problems prevent removal of cuda-gdb-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-gdb-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-gdb-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gdb-10-0
# dpkg: dependency problems prevent removal of cuda-gdb-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-gdb-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-gdb-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gdb-10-1
# dpkg: dependency problems prevent removal of cuda-gdb-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-gdb-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-gdb-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gdb-11-0
# dpkg: dependency problems prevent removal of cuda-gdb-11-1:
#  cuda-command-line-tools-11-1 depends on cuda-gdb-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-gdb-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gdb-11-1
# dpkg: dependency problems prevent removal of cuda-gdb-11-7:
#  cuda-command-line-tools-11-7 depends on cuda-gdb-11-7 (>= 11.7.91); however:
#   Package cuda-gdb-11-7 is to be removed.
#
# dpkg: error processing package cuda-gdb-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gdb-11-7
# dpkg: dependency problems prevent removal of cuda-gpu-library-advisor-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-gpu-library-advisor-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-gpu-library-advisor-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gpu-library-advisor-10-0
# dpkg: dependency problems prevent removal of cuda-gpu-library-advisor-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-gpu-library-advisor-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-gpu-library-advisor-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-gpu-library-advisor-10-1
# (Reading database ... 167099 files and directories currently installed.)
# Removing cuda-keyring (1.0-1) ...
# Purging configuration files for cuda-keyring (1.0-1) ...
# dpkg: dependency problems prevent removal of cuda-libraries-10-0:
#  cuda-runtime-10-0 depends on cuda-libraries-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-libraries-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-10-0
# dpkg: dependency problems prevent removal of cuda-libraries-10-1:
#  cuda-runtime-10-1 depends on cuda-libraries-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-libraries-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-10-1
# dpkg: dependency problems prevent removal of cuda-libraries-11-0:
#  cuda-toolkit-11-0 depends on cuda-libraries-11-0 (>= 11.0.3).
#  cuda-runtime-11-0 depends on cuda-libraries-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-libraries-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-11-0
# dpkg: dependency problems prevent removal of cuda-libraries-11-1:
#  cuda-toolkit-11-1 depends on cuda-libraries-11-1 (>= 11.1.1).
#  cuda-runtime-11-1 depends on cuda-libraries-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-libraries-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-11-1
# dpkg: dependency problems prevent removal of cuda-libraries-11-7:
#  cuda-runtime-11-7 depends on cuda-libraries-11-7 (>= 11.7.1).
#  cuda-toolkit-11-7 depends on cuda-libraries-11-7 (>= 11.7.1); however:
#   Package cuda-libraries-11-7 is to be removed.
#
# dpkg: error processing package cuda-libraries-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-11-7
# dpkg: dependency problems prevent removal of cuda-libraries-dev-10-0:
#  cuda-toolkit-10-0 depends on cuda-libraries-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-libraries-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-dev-10-0
# dpkg: dependency problems prevent removal of cuda-libraries-dev-10-1:
#  cuda-toolkit-10-1 depends on cuda-libraries-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-libraries-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-dev-10-1
# dpkg: dependency problems prevent removal of cuda-libraries-dev-11-0:
#  cuda-toolkit-11-0 depends on cuda-libraries-dev-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-libraries-dev-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-dev-11-0
# dpkg: dependency problems prevent removal of cuda-libraries-dev-11-1:
#  cuda-toolkit-11-1 depends on cuda-libraries-dev-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-libraries-dev-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-dev-11-1
# dpkg: dependency problems prevent removal of cuda-libraries-dev-11-7:
#  cuda-visual-tools-11-7 depends on cuda-libraries-dev-11-7 (>= 11.7.1); however:
#   Package cuda-libraries-dev-11-7 is to be removed.
#  cuda-toolkit-11-7 depends on cuda-libraries-dev-11-7 (>= 11.7.1); however:
#   Package cuda-libraries-dev-11-7 is to be removed.
#
# dpkg: error processing package cuda-libraries-dev-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-libraries-dev-11-7
# dpkg: dependency problems prevent removal of cuda-license-10-0:
#  cuda-cusolver-dev-10-0 depends on cuda-license-10-0.
#  cuda-cusparse-dev-10-0 depends on cuda-license-10-0.
#  cuda-curand-dev-10-0 depends on cuda-license-10-0.
#  cuda-nvtx-10-0 depends on cuda-license-10-0.
#  cuda-nvrtc-10-0 depends on cuda-license-10-0.
#  cuda-nvprof-10-0 depends on cuda-license-10-0.
#  cuda-nvcc-10-0 depends on cuda-license-10-0.
#  cuda-nvml-dev-10-0 depends on cuda-license-10-0.
#  cuda-nvdisasm-10-0 depends on cuda-license-10-0.
#  cuda-nsight-10-0 depends on cuda-license-10-0.
#  cuda-compiler-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-documentation-10-0 depends on cuda-license-10-0.
#  cuda-npp-dev-10-0 depends on cuda-license-10-0.
#  cuda-nvrtc-dev-10-0 depends on cuda-license-10-0.
#  cuda-memcheck-10-0 depends on cuda-license-10-0.
#  cuda-cudart-dev-10-0 depends on cuda-license-10-0.
#  cuda-toolkit-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-nvgraph-dev-10-0 depends on cuda-license-10-0.
#  cuda-cublas-10-0 depends on cuda-license-10-0.
#  cuda-gpu-library-advisor-10-0 depends on cuda-license-10-0.
#  cuda-driver-dev-10-0 depends on cuda-license-10-0.
#  cuda-curand-10-0 depends on cuda-license-10-0.
#  cuda-nvvp-10-0 depends on cuda-license-10-0.
#  cuda-misc-headers-10-0 depends on cuda-license-10-0.
#  cuda-cusolver-10-0 depends on cuda-license-10-0.
#  cuda-libraries-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-cufft-dev-10-0 depends on cuda-license-10-0.
#  cuda-npp-10-0 depends on cuda-license-10-0.
#  cuda-cudart-10-0 depends on cuda-license-10-0.
#  cuda-cupti-10-0 depends on cuda-license-10-0.
#  cuda-nsight-compute-10-0 depends on cuda-license-10-0.
#  cuda-cufft-10-0 depends on cuda-license-10-0.
#  cuda-nvjpeg-dev-10-0 depends on cuda-license-10-0.
#  cuda-gdb-10-0 depends on cuda-license-10-0.
#  cuda-nvjpeg-10-0 depends on cuda-license-10-0.
#  cuda-cuobjdump-10-0 depends on cuda-license-10-0.
#  cuda-cusparse-10-0 depends on cuda-license-10-0.
#  cuda-tools-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-libraries-dev-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-cublas-dev-10-0 depends on cuda-license-10-0.
#  cuda-nvprune-10-0 depends on cuda-license-10-0.
#  cuda-runtime-10-0 depends on cuda-license-10-0 (>= 10.0.130).
#  cuda-nvgraph-10-0 depends on cuda-license-10-0.
#
# dpkg: error processing package cuda-license-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-license-10-0
# dpkg: dependency problems prevent removal of cuda-license-10-1:
#  cuda-nsight-compute-10-1 depends on cuda-license-10-1; however:
#   Package cuda-license-10-1 is to be removed.
#  cuda-toolkit-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-nvgraph-dev-10-1 depends on cuda-license-10-1.
#  cuda-gdb-10-1 depends on cuda-license-10-1.
#  cuda-nsight-systems-10-1 depends on cuda-license-10-1; however:
#   Package cuda-license-10-1 is to be removed.
#  cuda-cuobjdump-10-1 depends on cuda-license-10-1.
#  cuda-driver-dev-10-1 depends on cuda-license-10-1.
#  cuda-nvvp-10-1 depends on cuda-license-10-1.
#  cuda-tools-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-libraries-dev-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-cusolver-dev-10-1 depends on cuda-license-10-1.
#  cuda-cufft-dev-10-1 depends on cuda-license-10-1.
#  cuda-npp-10-1 depends on cuda-license-10-1.
#  libcublas-dev depends on cuda-license-10-1.
#  cuda-curand-dev-10-1 depends on cuda-license-10-1.
#  libcublas10 depends on cuda-license-10-1.
#  cuda-nvrtc-10-1 depends on cuda-license-10-1.
#  cuda-nvprof-10-1 depends on cuda-license-10-1.
#  cuda-cufft-10-1 depends on cuda-license-10-1.
#  cuda-nvjpeg-dev-10-1 depends on cuda-license-10-1.
#  cuda-sanitizer-api-10-1 depends on cuda-license-10-1.
#  cuda-nvml-dev-10-1 depends on cuda-license-10-1.
#  cuda-nvdisasm-10-1 depends on cuda-license-10-1.
#  cuda-nsight-10-1 depends on cuda-license-10-1.
#  cuda-compiler-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-nvjpeg-10-1 depends on cuda-license-10-1.
#  cuda-cusparse-10-1 depends on cuda-license-10-1.
#  cuda-nvrtc-dev-10-1 depends on cuda-license-10-1.
#  cuda-cudart-dev-10-1 depends on cuda-license-10-1.
#  cuda-memcheck-10-1 depends on cuda-license-10-1.
#  cuda-nvprune-10-1 depends on cuda-license-10-1.
#  cuda-runtime-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-nvgraph-10-1 depends on cuda-license-10-1.
#  cuda-gpu-library-advisor-10-1 depends on cuda-license-10-1.
#  cuda-cusparse-dev-10-1 depends on cuda-license-10-1.
#  cuda-curand-10-1 depends on cuda-license-10-1.
#  cuda-nvtx-10-1 depends on cuda-license-10-1.
#  cuda-misc-headers-10-1 depends on cuda-license-10-1.
#  cuda-cusolver-10-1 depends on cuda-license-10-1.
#  cuda-nvcc-10-1 depends on cuda-license-10-1.
#  cuda-libraries-10-1 depends on cuda-license-10-1 (>= 10.1.243).
#  cuda-documentation-10-1 depends on cuda-license-10-1.
#  cuda-npp-dev-10-1 depends on cuda-license-10-1.
#  cuda-cudart-10-1 depends on cuda-license-10-1.
#  cuda-cupti-10-1 depends on cuda-license-10-1.
#
# dpkg: error processing package cuda-license-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-license-10-1
# dpkg: dependency problems prevent removal of cuda-memcheck-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-memcheck-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-memcheck-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-memcheck-10-0
# dpkg: dependency problems prevent removal of cuda-memcheck-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-memcheck-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-memcheck-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-memcheck-10-1
# dpkg: dependency problems prevent removal of cuda-memcheck-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-memcheck-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-memcheck-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-memcheck-11-0
# dpkg: dependency problems prevent removal of cuda-memcheck-11-1:
#  cuda-command-line-tools-11-1 depends on cuda-memcheck-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-memcheck-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-memcheck-11-1
# dpkg: dependency problems prevent removal of cuda-memcheck-11-7:
#  cuda-command-line-tools-11-7 depends on cuda-memcheck-11-7 (>= 11.7.91); however:
#   Package cuda-memcheck-11-7 is to be removed.
#
# dpkg: error processing package cuda-memcheck-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-memcheck-11-7
# (Reading database ... 167094 files and directories currently installed.)
# Removing cuda-minimal-build-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-misc-headers-10-0:
#  cuda-nvcc-10-0 depends on cuda-misc-headers-10-0 (>= 10.0.130).
#  cuda-libraries-dev-10-0 depends on cuda-misc-headers-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-misc-headers-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-misc-headers-10-0
# dpkg: dependency problems prevent removal of cuda-misc-headers-10-1:
#  cuda-libraries-dev-10-1 depends on cuda-misc-headers-10-1 (>= 10.1.243).
#  cuda-nvcc-10-1 depends on cuda-misc-headers-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-misc-headers-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-misc-headers-10-1
# dpkg: dependency problems prevent removal of cuda-npp-10-0:
#  cuda-npp-dev-10-0 depends on cuda-npp-10-0 (>= 10.0.130).
#  cuda-libraries-10-0 depends on cuda-npp-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-npp-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-npp-10-0
# dpkg: dependency problems prevent removal of cuda-npp-10-1:
#  cuda-libraries-10-1 depends on cuda-npp-10-1 (>= 10.1.243).
#  cuda-npp-dev-10-1 depends on cuda-npp-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-npp-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-npp-10-1
# dpkg: dependency problems prevent removal of cuda-npp-dev-10-0:
#  cuda-visual-tools-10-0 depends on cuda-npp-dev-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-npp-dev-10-0.
#  cuda-libraries-dev-10-0 depends on cuda-npp-dev-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-npp-dev-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-npp-dev-10-0
# dpkg: dependency problems prevent removal of cuda-npp-dev-10-1:
#  cuda-samples-10-1 depends on cuda-npp-dev-10-1.
#  cuda-libraries-dev-10-1 depends on cuda-npp-dev-10-1 (>= 10.1.243).
#  cuda-visual-tools-10-1 depends on cuda-npp-dev-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-npp-dev-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-npp-dev-10-1
# dpkg: dependency problems prevent removal of cuda-nsight-10-0:
#  cuda-visual-tools-10-0 depends on cuda-nsight-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-nsight-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-10-0
# dpkg: dependency problems prevent removal of cuda-nsight-10-1:
#  cuda-visual-tools-10-1 depends on cuda-nsight-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nsight-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-10-1
# dpkg: dependency problems prevent removal of cuda-nsight-11-0:
#  cuda-visual-tools-11-0 depends on cuda-nsight-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-nsight-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-11-0
# dpkg: dependency problems prevent removal of cuda-nsight-11-1:
#  cuda-visual-tools-11-1 depends on cuda-nsight-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-nsight-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-11-1
# dpkg: dependency problems prevent removal of cuda-nsight-11-7:
#  cuda-visual-tools-11-7 depends on cuda-nsight-11-7 (>= 11.7.91); however:
#   Package cuda-nsight-11-7 is to be removed.
#
# dpkg: error processing package cuda-nsight-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-11-7
# dpkg: dependency problems prevent removal of cuda-nsight-compute-10-0:
#  cuda-visual-tools-10-0 depends on cuda-nsight-compute-10-0.
#
# dpkg: error processing package cuda-nsight-compute-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-compute-10-0
# dpkg: dependency problems prevent removal of cuda-nsight-compute-10-1:
#  cuda-visual-tools-10-1 depends on cuda-nsight-compute-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nsight-compute-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-compute-10-1
# dpkg: dependency problems prevent removal of cuda-nsight-compute-11-0:
#  cuda-visual-tools-11-0 depends on cuda-nsight-compute-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-nsight-compute-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-compute-11-0
# dpkg: dependency problems prevent removal of cuda-nsight-compute-11-1:
#  cuda-visual-tools-11-1 depends on cuda-nsight-compute-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-nsight-compute-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-compute-11-1
# dpkg: dependency problems prevent removal of cuda-nsight-compute-11-7:
#  cuda-visual-tools-11-7 depends on cuda-nsight-compute-11-7 (>= 11.7.1).
#
# dpkg: error processing package cuda-nsight-compute-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-compute-11-7
# dpkg: dependency problems prevent removal of cuda-nsight-systems-10-1:
#  cuda-visual-tools-10-1 depends on cuda-nsight-systems-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nsight-systems-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-systems-10-1
# dpkg: dependency problems prevent removal of cuda-nsight-systems-11-0:
#  cuda-visual-tools-11-0 depends on cuda-nsight-systems-11-0 (>= 11.0.3).
#
# dpkg: error processing package cuda-nsight-systems-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-systems-11-0
# dpkg: dependency problems prevent removal of cuda-nsight-systems-11-1:
#  cuda-visual-tools-11-1 depends on cuda-nsight-systems-11-1 (>= 11.1.1).
#
# dpkg: error processing package cuda-nsight-systems-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-systems-11-1
# dpkg: dependency problems prevent removal of cuda-nsight-systems-11-7:
#  cuda-visual-tools-11-7 depends on cuda-nsight-systems-11-7 (>= 11.7.1); however:
#   Package cuda-nsight-systems-11-7 is to be removed.
#
# dpkg: error processing package cuda-nsight-systems-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nsight-systems-11-7
# dpkg: dependency problems prevent removal of cuda-nvcc-10-0:
#  cuda-compiler-10-0 depends on cuda-nvcc-10-0 (>= 10.0.130).
#  cuda-cupti-10-0 depends on cuda-nvcc-10-0 (>= 10.0.130).
#  cuda-samples-10-0 depends on cuda-nvcc-10-0.
#
# dpkg: error processing package cuda-nvcc-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvcc-10-0
# dpkg: dependency problems prevent removal of cuda-nvcc-10-1:
#  cuda-samples-10-1 depends on cuda-nvcc-10-1.
#  cuda-compiler-10-1 depends on cuda-nvcc-10-1 (>= 10.1.243).
#  cuda-cupti-10-1 depends on cuda-nvcc-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nvcc-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvcc-10-1
# dpkg: dependency problems prevent removal of cuda-nvcc-11-0:
#  cuda-cupti-11-0 depends on cuda-nvcc-11-0.
#  cuda-compiler-11-0 depends on cuda-nvcc-11-0 (>= 11.0.221).
#  cuda-samples-11-0 depends on cuda-nvcc-11-0.
#
# dpkg: error processing package cuda-nvcc-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvcc-11-0
# dpkg: dependency problems prevent removal of cuda-nvcc-11-1:
#  cuda-samples-11-1 depends on cuda-nvcc-11-1.
#  cuda-cupti-11-1 depends on cuda-nvcc-11-1.
#  cuda-compiler-11-1 depends on cuda-nvcc-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-nvcc-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvcc-11-1
# dpkg: dependency problems prevent removal of cuda-nvcc-11-7:
#  cuda-compiler-11-7 depends on cuda-nvcc-11-7 (>= 11.7.99); however:
#   Package cuda-nvcc-11-7 is to be removed.
#  cuda-cupti-11-7 depends on cuda-nvcc-11-7; however:
#   Package cuda-nvcc-11-7 is to be removed.
#
# dpkg: error processing package cuda-nvcc-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvcc-11-7
# dpkg: dependency problems prevent removal of cuda-nvdisasm-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-nvdisasm-10-0 (>= 10.0.130).
#  cuda-gdb-10-0 depends on cuda-nvdisasm-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-nvdisasm-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvdisasm-10-0
# dpkg: dependency problems prevent removal of cuda-nvdisasm-10-1:
#  cuda-gdb-10-1 depends on cuda-nvdisasm-10-1 (>= 10.1.243).
#  cuda-command-line-tools-10-1 depends on cuda-nvdisasm-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nvdisasm-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvdisasm-10-1
# dpkg: dependency problems prevent removal of cuda-nvdisasm-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-nvdisasm-11-0 (>= 11.0.221).
#  cuda-gdb-11-0 depends on cuda-nvdisasm-11-0.
#
# dpkg: error processing package cuda-nvdisasm-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvdisasm-11-0
# ...
# Errors were encountered while processing:
#  cuda-nvrtc-dev-11-0
# dpkg: dependency problems prevent removal of cuda-nvrtc-dev-11-1:
#  cuda-samples-11-1 depends on cuda-nvrtc-dev-11-1.
#  cuda-visual-tools-11-1 depends on cuda-nvrtc-dev-11-1 (>= 11.1.105).
#  cuda-libraries-dev-11-1 depends on cuda-nvrtc-dev-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-nvrtc-dev-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvrtc-dev-11-1
# dpkg: dependency problems prevent removal of cuda-nvrtc-dev-11-7:
#  cuda-libraries-dev-11-7 depends on cuda-nvrtc-dev-11-7 (>= 11.7.99); however:
#   Package cuda-nvrtc-dev-11-7 is to be removed.
#
# dpkg: error processing package cuda-nvrtc-dev-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvrtc-dev-11-7
# dpkg: dependency problems prevent removal of cuda-nvtx-10-0:
#  cuda-command-line-tools-10-0 depends on cuda-nvtx-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-nvtx-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvtx-10-0
# dpkg: dependency problems prevent removal of cuda-nvtx-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-nvtx-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nvtx-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvtx-10-1
# dpkg: dependency problems prevent removal of cuda-nvtx-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-nvtx-11-0 (>= 11.0.167).
#
# dpkg: error processing package cuda-nvtx-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvtx-11-0
# dpkg: dependency problems prevent removal of cuda-nvtx-11-1:
#  cuda-command-line-tools-11-1 depends on cuda-nvtx-11-1 (>= 11.1.74).
#
# dpkg: error processing package cuda-nvtx-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvtx-11-1
# dpkg: dependency problems prevent removal of cuda-nvtx-11-7:
#  cuda-command-line-tools-11-7 depends on cuda-nvtx-11-7 (>= 11.7.91); however:
#   Package cuda-nvtx-11-7 is to be removed.
#
# dpkg: error processing package cuda-nvtx-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvtx-11-7
# dpkg: dependency problems prevent removal of cuda-nvvp-10-0:
#  cuda-visual-tools-10-0 depends on cuda-nvvp-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-nvvp-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvvp-10-0
# dpkg: dependency problems prevent removal of cuda-nvvp-10-1:
#  cuda-visual-tools-10-1 depends on cuda-nvvp-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-nvvp-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvvp-10-1
# dpkg: dependency problems prevent removal of cuda-nvvp-11-0:
#  cuda-visual-tools-11-0 depends on cuda-nvvp-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-nvvp-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvvp-11-0
# dpkg: dependency problems prevent removal of cuda-nvvp-11-1:
#  cuda-visual-tools-11-1 depends on cuda-nvvp-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-nvvp-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvvp-11-1
# dpkg: dependency problems prevent removal of cuda-nvvp-11-7:
#  cuda-visual-tools-11-7 depends on cuda-nvvp-11-7 (>= 11.7.101); however:
#   Package cuda-nvvp-11-7 is to be removed.
#
# dpkg: error processing package cuda-nvvp-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-nvvp-11-7
# (Reading database ... 167092 files and directories currently installed.)
# Removing cuda-runtime-10-0 (10.0.130-1) ...
# (Reading database ... 167089 files and directories currently installed.)
# Removing cuda-runtime-10-1 (10.1.243-1) ...
# (Reading database ... 167086 files and directories currently installed.)
# Removing cuda-runtime-11-0 (11.0.3-1) ...
# (Reading database ... 167084 files and directories currently installed.)
# Removing cuda-runtime-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-runtime-11-7:
#  cuda-demo-suite-11-7 depends on cuda-runtime-11-7.
#  cuda-11-7 depends on cuda-runtime-11-7 (>= 11.7.1).
#
# dpkg: error processing package cuda-runtime-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-runtime-11-7
# dpkg: dependency problems prevent removal of cuda-samples-10-0:
#  cuda-documentation-10-0 depends on cuda-samples-10-0.
#  cuda-toolkit-10-0 depends on cuda-samples-10-0 (>= 10.0.130).
#
# dpkg: error processing package cuda-samples-10-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-samples-10-0
# dpkg: dependency problems prevent removal of cuda-samples-10-1:
#  cuda-toolkit-10-1 depends on cuda-samples-10-1 (>= 10.1.243).
#  cuda-documentation-10-1 depends on cuda-samples-10-1.
#
# dpkg: error processing package cuda-samples-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-samples-10-1
# dpkg: dependency problems prevent removal of cuda-samples-11-0:
#  cuda-documentation-11-0 depends on cuda-samples-11-0.
#  cuda-toolkit-11-0 depends on cuda-samples-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-samples-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-samples-11-0
# dpkg: dependency problems prevent removal of cuda-samples-11-1:
#  cuda-documentation-11-1 depends on cuda-samples-11-1.
#  cuda-toolkit-11-1 depends on cuda-samples-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-samples-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-samples-11-1
# dpkg: dependency problems prevent removal of cuda-sanitizer-11-0:
#  cuda-command-line-tools-11-0 depends on cuda-sanitizer-11-0 (>= 11.0.221).
#
# dpkg: error processing package cuda-sanitizer-11-0 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-sanitizer-11-0
# dpkg: dependency problems prevent removal of cuda-sanitizer-11-1:
#  cuda-command-line-tools-11-1 depends on cuda-sanitizer-11-1 (>= 11.1.105).
#
# dpkg: error processing package cuda-sanitizer-11-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-sanitizer-11-1
# dpkg: dependency problems prevent removal of cuda-sanitizer-11-7:
#  cuda-command-line-tools-11-7 depends on cuda-sanitizer-11-7 (>= 11.7.91); however:
#   Package cuda-sanitizer-11-7 is to be removed.
#
# dpkg: error processing package cuda-sanitizer-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-sanitizer-11-7
# dpkg: dependency problems prevent removal of cuda-sanitizer-api-10-1:
#  cuda-command-line-tools-10-1 depends on cuda-sanitizer-api-10-1 (>= 10.1.243).
#
# dpkg: error processing package cuda-sanitizer-api-10-1 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-sanitizer-api-10-1
# (Reading database ... 167082 files and directories currently installed.)
# Removing cuda-toolkit-10-0 (10.0.130-1) ...
# Purging configuration files for cuda-toolkit-10-0 (10.0.130-1) ...
# (Reading database ... 167079 files and directories currently installed.)
# Removing cuda-toolkit-10-1 (10.1.243-1) ...
# Purging configuration files for cuda-toolkit-10-1 (10.1.243-1) ...
# (Reading database ... 167076 files and directories currently installed.)
# Removing cuda-toolkit-11-0 (11.0.3-1) ...
# Purging configuration files for cuda-toolkit-11-0 (11.0.3-1) ...
# (Reading database ... 167074 files and directories currently installed.)
# Removing cuda-toolkit-11-1 (11.1.1-1) ...
# Purging configuration files for cuda-toolkit-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-toolkit-11-7:
#  cuda-11-7 depends on cuda-toolkit-11-7 (>= 11.7.1); however:
#   Package cuda-toolkit-11-7 is to be removed.
#
# dpkg: error processing package cuda-toolkit-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-toolkit-11-7
# dpkg: dependency problems prevent removal of cuda-toolkit-11-7-config-common:
#  libcufile-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcublas-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libnvjpeg-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libnpp-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcusolver-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcusparse-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcufft-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcurand-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  cuda-cudart-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#
# dpkg: error processing package cuda-toolkit-11-7-config-common (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-toolkit-11-7-config-common
# dpkg: dependency problems prevent removal of cuda-toolkit-11-config-common:
#  libcufile-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcublas-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnvjpeg-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnpp-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusolver-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusparse-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcufft-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcurand-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  cuda-cudart-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#
# dpkg: error processing package cuda-toolkit-11-config-common (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-toolkit-11-config-common
# dpkg: dependency problems prevent removal of cuda-toolkit-config-common:
#  libcufile-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcublas-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnvjpeg-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnpp-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusolver-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusparse-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcufft-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcurand-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  cuda-cudart-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#
# dpkg: error processing package cuda-toolkit-config-common (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-toolkit-config-common
# (Reading database ... 167072 files and directories currently installed.)
# Removing cuda-tools-10-0 (10.0.130-1) ...
# (Reading database ... 167069 files and directories currently installed.)
# Removing cuda-tools-10-1 (10.1.243-1) ...
# (Reading database ... 167066 files and directories currently installed.)
# Removing cuda-tools-11-0 (11.0.3-1) ...
# (Reading database ... 167064 files and directories currently installed.)
# Removing cuda-tools-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-tools-11-7:
#  cuda-toolkit-11-7 depends on cuda-tools-11-7 (>= 11.7.1); however:
#   Package cuda-tools-11-7 is to be removed.
#
# dpkg: error processing package cuda-tools-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-tools-11-7
# (Reading database ... 167062 files and directories currently installed.)
# Removing cuda-visual-tools-10-0 (10.0.130-1) ...
# Purging configuration files for cuda-visual-tools-10-0 (10.0.130-1) ...
# (Reading database ... 164229 files and directories currently installed.)
# Removing cuda-visual-tools-10-1 (10.1.243-1) ...
# Purging configuration files for cuda-visual-tools-10-1 (10.1.243-1) ...
# (Reading database ... 161396 files and directories currently installed.)
# Removing cuda-visual-tools-11-0 (11.0.3-1) ...
# Purging configuration files for cuda-visual-tools-11-0 (11.0.3-1) ...
# (Reading database ... 161394 files and directories currently installed.)
# Removing cuda-visual-tools-11-1 (11.1.1-1) ...
# Purging configuration files for cuda-visual-tools-11-1 (11.1.1-1) ...
# dpkg: dependency problems prevent removal of cuda-visual-tools-11-7:
#  cuda-tools-11-7 depends on cuda-visual-tools-11-7 (>= 11.7.1); however:
#   Package cuda-visual-tools-11-7 is to be removed.
#
# dpkg: error processing package cuda-visual-tools-11-7 (--purge):
#  dependency problems - not removing
# Errors were encountered while processing:
#  cuda-visual-tools-11-7
# (Reading database ... 161392 files and directories currently installed.)
# Removing nvidia-cuda-doc (9.1.85-3ubuntu1) ...
# (Reading database ... 159797 files and directories currently installed.)
# Removing nvidia-cuda-gdb (9.1.85-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# (Reading database ... 159788 files and directories currently installed.)
# Removing nvidia-cuda-toolkit (9.1.85-3ubuntu1) ...
# Purging configuration files for nvidia-cuda-toolkit (9.1.85-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !apt-get remove cuda-*
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-nsight-compute-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-compute-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-compute-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvprof-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvprof-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvprof-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvprune-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvprune-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-toolkit-11-config-common' for glob 'cuda-*'
# Note, selecting 'cuda-nvprune-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvprune-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvprune-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvgraph-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvgraph-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cublas-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-515' for glob 'cuda-*'
# Note, selecting 'cuda-gdb-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-gdb-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-gdb-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-gdb-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-gdb-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-curand-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-curand-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-visual-tools-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-branch' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1204' for glob 'cuda-*'
# Note, selecting 'cuda-nvjpeg-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvjpeg-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-10-2' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cccl-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-drivers' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1404' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1410' for glob 'cuda-*'
# Note, selecting 'cuda-thrust-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1504' for glob 'cuda-*'
# Note, selecting 'cuda-license-7-5' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-toolkit-11-7-config-common' for glob 'cuda-*'
# Note, selecting 'cuda-cusolver-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cusolver-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-cupti-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-libraries-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-diagnostic' for glob 'cuda-*'
# Note, selecting 'cuda-runtime-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cusparse-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cusparse-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-sanitizer-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-sanitizer-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-sanitizer-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-10-2' for glob 'cuda-*'
# Note, selecting 'cuda-nvjpeg-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvjpeg-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cufft-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cufft-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-systems-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvrtc-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cusparse-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cusparse-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-systems-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-systems-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-systems-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-npp-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-npp-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvtx-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvtx-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-tools-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvtx-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvtx-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvtx-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-10-2' for glob 'cuda-*'
# Note, selecting 'cuda-license-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-license-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvdisasm-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvdisasm-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-samples-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-samples-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-documentation-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-documentation-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-11-2' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvdisasm-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvdisasm-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvdisasm-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-samples-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-samples-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-documentation-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-documentation-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-documentation-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvcc-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvcc-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1404-7-5-local' for glob 'cuda-*'
# Note, selecting 'cuda-nvvp-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvvp-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvcc-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvcc-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvcc-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvvp-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvvp-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvvp-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvgraph-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvgraph-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cuxxfilt-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cub-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-toolkit-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-10-2' for glob 'cuda-*'
# Note, selecting 'cuda-nvml-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvml-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-cudart-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nvml-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvml-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvml-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-gpu-library-advisor-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-gpu-library-advisor-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cublas-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cusolver-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cusolver-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-sanitizer-api-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-compiler-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-compiler-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-npp-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-npp-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-compiler-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-compiler-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-compiler-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-demo-suite-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-curand-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-curand-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-command-line-tools-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-command-line-tools-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cufft-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cufft-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager-450' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager-460' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager-470' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-driver-dev-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-driver-dev-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-repo-ubuntu1504-7-5-local' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager-510' for glob 'cuda-*'
# Note, selecting 'cuda-command-line-tools-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-command-line-tools-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager-515' for glob 'cuda-*'
# Note, selecting 'cuda-command-line-tools-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-driver-dev-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-driver-dev-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-driver-dev-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-drivers-fabricmanager' for glob 'cuda-*'
# Note, selecting 'cuda-memcheck-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-memcheck-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-memcheck-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-memcheck-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-memcheck-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-toolkit-config-common' for glob 'cuda-*'
# Note, selecting 'cuda-misc-headers-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-misc-headers-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cuobjdump-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-cuobjdump-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-cuobjdump-11-0' for glob 'cuda-*'
# Note, selecting 'cuda-cuobjdump-11-1' for glob 'cuda-*'
# Note, selecting 'cuda-cuobjdump-11-7' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-compute-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nsight-compute-10-1' for glob 'cuda-*'
# Note, selecting 'cuda-nvprof-10-0' for glob 'cuda-*'
# Note, selecting 'cuda-nvprof-10-1' for glob 'cuda-*'
# Package 'cuda-license-7-5' is not installed, so not removed
# Package 'cuda-repo-ubuntu1204' is not installed, so not removed
# Package 'cuda-repo-ubuntu1404' is not installed, so not removed
# Package 'cuda-repo-ubuntu1404-7-5-local' is not installed, so not removed
# Package 'cuda-repo-ubuntu1410' is not installed, so not removed
# Package 'cuda-repo-ubuntu1504' is not installed, so not removed
# Package 'cuda-repo-ubuntu1504-7-5-local' is not installed, so not removed
# Package 'cuda-cudart-dev-10-2' is not installed, so not removed
# Package 'cuda-nvrtc-dev-10-2' is not installed, so not removed
# Package 'cuda-nvrtc-10-2' is not installed, so not removed
# Package 'cuda-cudart-10-2' is not installed, so not removed
# Package 'cuda-cudart-11-2' is not installed, so not removed
# Note, selecting 'cuda-drivers-515' instead of 'cuda-drivers-branch'
# Note, selecting 'cuda-cccl-11-7' instead of 'cuda-cub-11-7'
# Note, selecting 'cuda-cccl-11-7' instead of 'cuda-thrust-11-7'
# Package 'cuda-drivers-diagnostic' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-515' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-450' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-460' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-470' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-510' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   default-jre dkms fonts-dejavu-extra freeglut3 freeglut3-dev g++-6
#   gds-tools-11-7 keyboard-configuration libaccinj64-9.1 libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libcublas-dev-11-0 libcublas9.1 libcudart9.1 libcufft-11-0 libcufft-11-1
#   libcufft-dev-11-0 libcufft-dev-11-1 libcufft9.1 libcufftw9.1 libcuinj64-9.1
#   libcurand-11-0 libcurand-11-1 libcurand-dev-11-0 libcurand-dev-11-1
#   libcurand9.1 libcusolver-11-0 libcusolver-11-1 libcusolver-dev-11-0
#   libcusolver-dev-11-1 libcusolver9.1 libcusparse-11-0 libcusparse-dev-11-0
#   libcusparse9.1 libdevmapper1.02.1 libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libidn11 libip4tc0 libjansson4 libnpp-11-0
#   libnpp-dev-11-0 libnppc9.1 libnppial9.1 libnppicc9.1 libnppicom9.1
#   libnppidei9.1 libnppif9.1 libnppig9.1 libnppim9.1 libnppist9.1 libnppisu9.1
#   libnppitc9.1 libnpps9.1 libnvblas9.1 libnvgraph9.1 libnvidia-cfg1-515
#   libnvidia-common-460 libnvidia-common-515 libnvidia-decode-515
#   libnvidia-encode-515 libnvidia-extra-515 libnvidia-fbc1-515 libnvidia-gl-515
#   libnvjpeg-11-0 libnvjpeg-11-1 libnvjpeg-dev-11-0 libnvjpeg-dev-11-1
#   libnvrtc9.1 libnvtoolsext1 libnvvm3 libpam-systemd libpolkit-agent-1-0
#   libpolkit-backend-1-0 libpolkit-gobject-1-0 libthrust-dev libvdpau-dev
#   libxfont2 libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0
#   nsight-compute-2020.2.1 nsight-compute-2022.2.1 nsight-systems-2020.3.2
#   nsight-systems-2020.3.4 nsight-systems-2022.1.3 nvidia-compute-utils-515
#   nvidia-dkms-515 nvidia-driver-515 nvidia-kernel-common-515
#   nvidia-kernel-source-515 nvidia-modprobe nvidia-profiler nvidia-settings
#   nvidia-utils-515 nvidia-visual-profiler openjdk-11-jre openjdk-8-jre
#   policykit-1 policykit-1-gnome python3-xkit screen-resolution-extra systemd
#   systemd-sysv udev x11-xkb-utils xserver-common xserver-xorg-core-hwe-18.04
#   xserver-xorg-video-nvidia-515
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   cuda cuda-11-7 cuda-cccl-11-7 cuda-command-line-tools-10-0
#   cuda-command-line-tools-10-1 cuda-command-line-tools-11-0
#   cuda-command-line-tools-11-1 cuda-command-line-tools-11-7 cuda-compiler-10-0
#   cuda-compiler-10-1 cuda-compiler-11-0 cuda-compiler-11-1 cuda-compiler-11-7
#   cuda-cublas-10-0 cuda-cublas-dev-10-0 cuda-cudart-10-0 cuda-cudart-10-1
#   cuda-cudart-11-0 cuda-cudart-11-1 cuda-cudart-11-7 cuda-cudart-dev-10-0
#   cuda-cudart-dev-10-1 cuda-cudart-dev-11-0 cuda-cudart-dev-11-1
#   cuda-cudart-dev-11-7 cuda-cufft-10-0 cuda-cufft-10-1 cuda-cufft-dev-10-0
#   cuda-cufft-dev-10-1 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cuobjdump-11-1 cuda-cuobjdump-11-7 cuda-cupti-10-0
#   cuda-cupti-10-1 cuda-cupti-11-0 cuda-cupti-11-1 cuda-cupti-11-7
#   cuda-cupti-dev-11-0 cuda-cupti-dev-11-1 cuda-cupti-dev-11-7 cuda-curand-10-0
#   cuda-curand-10-1 cuda-curand-dev-10-0 cuda-curand-dev-10-1
#   cuda-cusolver-10-0 cuda-cusolver-10-1 cuda-cusolver-dev-10-0
#   cuda-cusolver-dev-10-1 cuda-cusparse-10-0 cuda-cusparse-10-1
#   cuda-cusparse-dev-10-0 cuda-cusparse-dev-10-1 cuda-cuxxfilt-11-7
#   cuda-demo-suite-11-7 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-documentation-11-7
#   cuda-driver-dev-10-0 cuda-driver-dev-10-1 cuda-driver-dev-11-0
#   cuda-driver-dev-11-1 cuda-driver-dev-11-7 cuda-drivers cuda-drivers-515
#   cuda-gdb-10-0 cuda-gdb-10-1 cuda-gdb-11-0 cuda-gdb-11-1 cuda-gdb-11-7
#   cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-libraries-11-1 cuda-libraries-11-7 cuda-libraries-dev-10-0
#   cuda-libraries-dev-10-1 cuda-libraries-dev-11-0 cuda-libraries-dev-11-1
#   cuda-libraries-dev-11-7 cuda-license-10-0 cuda-license-10-1
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-memcheck-11-1
#   cuda-memcheck-11-7 cuda-misc-headers-10-0 cuda-misc-headers-10-1
#   cuda-npp-10-0 cuda-npp-10-1 cuda-npp-dev-10-0 cuda-npp-dev-10-1
#   cuda-nsight-10-0 cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1
#   cuda-nsight-11-7 cuda-nsight-compute-10-0 cuda-nsight-compute-10-1
#   cuda-nsight-compute-11-0 cuda-nsight-compute-11-1 cuda-nsight-compute-11-7
#   cuda-nsight-systems-10-1 cuda-nsight-systems-11-0 cuda-nsight-systems-11-1
#   cuda-nsight-systems-11-7 cuda-nvcc-10-0 cuda-nvcc-10-1 cuda-nvcc-11-0
#   cuda-nvcc-11-1 cuda-nvcc-11-7 cuda-nvdisasm-10-0 cuda-nvdisasm-10-1
#   cuda-nvdisasm-11-0 cuda-nvdisasm-11-1 cuda-nvdisasm-11-7 cuda-nvgraph-10-0
#   cuda-nvgraph-10-1 cuda-nvgraph-dev-10-0 cuda-nvgraph-dev-10-1
#   cuda-nvjpeg-10-0 cuda-nvjpeg-10-1 cuda-nvjpeg-dev-10-0 cuda-nvjpeg-dev-10-1
#   cuda-nvml-dev-10-0 cuda-nvml-dev-10-1 cuda-nvml-dev-11-0 cuda-nvml-dev-11-1
#   cuda-nvml-dev-11-7 cuda-nvprof-10-0 cuda-nvprof-10-1 cuda-nvprof-11-0
#   cuda-nvprof-11-1 cuda-nvprof-11-7 cuda-nvprune-10-0 cuda-nvprune-10-1
#   cuda-nvprune-11-0 cuda-nvprune-11-1 cuda-nvprune-11-7 cuda-nvrtc-10-0
#   cuda-nvrtc-10-1 cuda-nvrtc-11-0 cuda-nvrtc-11-1 cuda-nvrtc-11-7
#   cuda-nvrtc-dev-10-0 cuda-nvrtc-dev-10-1 cuda-nvrtc-dev-11-0
#   cuda-nvrtc-dev-11-1 cuda-nvrtc-dev-11-7 cuda-nvtx-10-0 cuda-nvtx-10-1
#   cuda-nvtx-11-0 cuda-nvtx-11-1 cuda-nvtx-11-7 cuda-nvvp-10-0 cuda-nvvp-10-1
#   cuda-nvvp-11-0 cuda-nvvp-11-1 cuda-nvvp-11-7 cuda-runtime-11-7
#   cuda-samples-10-0 cuda-samples-10-1 cuda-samples-11-0 cuda-samples-11-1
#   cuda-sanitizer-11-0 cuda-sanitizer-11-1 cuda-sanitizer-11-7
#   cuda-sanitizer-api-10-1 cuda-toolkit-11-7 cuda-toolkit-11-7-config-common
#   cuda-toolkit-11-config-common cuda-toolkit-config-common cuda-tools-11-7
#   cuda-visual-tools-11-7 libcublas-11-7 libcublas-dev libcublas-dev-11-7
#   libcublas10 libcufft-11-7 libcufft-dev-11-7 libcufile-11-7
#   libcufile-dev-11-7 libcurand-11-7 libcurand-dev-11-7 libcusolver-11-7
#   libcusolver-dev-11-7 libcusparse-11-7 libcusparse-dev-11-7 libnpp-11-7
#   libnpp-dev-11-7 libnvjpeg-11-7 libnvjpeg-dev-11-7
# 0 upgraded, 0 newly installed, 198 to remove and 21 not upgraded.
# 105 not fully installed or removed.
# After this operation, 11.7 GB disk space will be freed.
# (Reading database ... 159746 files and directories currently installed.)
# Removing cuda (11.7.1-1) ...
# Removing cuda-11-7 (11.7.1-1) ...
# Removing cuda-toolkit-11-7 (11.7.1-1) ...
# Removing alternatives
# Removing cuda-tools-11-7 (11.7.1-1) ...
# Removing cuda-visual-tools-11-7 (11.7.1-1) ...
# Removing cuda-libraries-dev-11-7 (11.7.1-1) ...
# Removing cuda-compiler-11-7 (11.7.1-1) ...
# Removing cuda-command-line-tools-11-7 (11.7.1-1) ...
# Removing cuda-demo-suite-11-7 (11.7.91-1) ...
# Removing cuda-runtime-11-7 (11.7.1-1) ...
# Removing cuda-libraries-11-7 (11.7.1-1) ...
# Removing cuda-cupti-dev-11-7 (11.7.101-1) ...
# Removing cuda-cupti-11-7 (11.7.101-1) ...
# Removing cuda-gdb-11-7 (11.7.91-1) ...
# Removing cuda-cuobjdump-11-7 (11.7.91-1) ...
# Removing cuda-cuxxfilt-11-7 (11.7.91-1) ...
# Removing cuda-documentation-11-7 (11.7.91-1) ...
# Removing cuda-memcheck-11-7 (11.7.91-1) ...
# Removing cuda-nsight-11-7 (11.7.91-1) ...
# Removing cuda-nsight-compute-11-7 (11.7.1-1) ...
# Removing cuda-nsight-systems-11-7 (11.7.1-1) ...
# Removing cuda-nvdisasm-11-7 (11.7.91-1) ...
# Removing cuda-nvml-dev-11-7 (11.7.91-1) ...
# Removing cuda-nvprof-11-7 (11.7.101-1) ...
# Removing cuda-nvprune-11-7 (11.7.91-1) ...
# Removing cuda-nvrtc-dev-11-7 (11.7.99-1) ...
# Removing cuda-nvrtc-11-7 (11.7.99-1) ...
# Removing cuda-nvtx-11-7 (11.7.91-1) ...
# Removing cuda-nvvp-11-7 (11.7.101-1) ...
# Removing cuda-sanitizer-11-7 (11.7.91-1) ...
# Removing libcufile-dev-11-7 (1.3.1.18-1) ...
# Removing libcufile-11-7 (1.3.1.18-1) ...
# Removing libcublas-dev-11-7 (11.10.3.66-1) ...
# Removing libcublas-11-7 (11.10.3.66-1) ...
# Removing libnvjpeg-dev-11-7 (11.8.0.2-1) ...
# Removing libnvjpeg-11-7 (11.8.0.2-1) ...
# Removing libnpp-dev-11-7 (11.7.4.75-1) ...
# Removing libnpp-11-7 (11.7.4.75-1) ...
# Removing libcufft-dev-11-7 (10.7.2.91-1) ...
# Removing libcufft-11-7 (10.7.2.91-1) ...
# Removing libcurand-dev-11-7 (10.2.10.91-1) ...
# Removing libcurand-11-7 (10.2.10.91-1) ...
# Removing libcusolver-dev-11-7 (11.4.0.1-1) ...
# Removing libcusolver-11-7 (11.4.0.1-1) ...
# Removing libcusparse-dev-11-7 (11.7.4.91-1) ...
# Removing libcusparse-11-7 (11.7.4.91-1) ...
# Removing cuda-command-line-tools-10-0 (10.0.130-1) ...
# Removing cuda-command-line-tools-10-1 (10.1.243-1) ...
# Removing cuda-command-line-tools-11-0 (11.0.3-1) ...
# Removing cuda-command-line-tools-11-1 (11.1.1-1) ...
# Removing cuda-compiler-10-0 (10.0.130-1) ...
# Removing cuda-compiler-10-1 (10.1.243-1) ...
# Removing cuda-compiler-11-0 (11.0.3-1) ...
# Removing cuda-compiler-11-1 (11.1.1-1) ...
# Removing cuda-libraries-dev-10-0 (10.0.130-1) ...
# Removing cuda-documentation-10-0 (10.0.130-1) ...
# Removing cuda-samples-10-0 (10.0.130-1) ...
# Removing cuda-cublas-dev-10-0 (10.0.130-1) ...
# Removing cuda-libraries-10-0 (10.0.130-1) ...
# Removing cuda-cublas-10-0 (10.0.130-1) ...
# Removing cuda-cupti-10-0 (10.0.130-1) ...
# Removing cuda-cudart-dev-10-0 (10.0.130-1) ...
# Removing cuda-cudart-10-0 (10.0.130-1) ...
# Removing cuda-libraries-10-1 (10.1.243-1) ...
# Removing cuda-cupti-10-1 (10.1.243-1) ...
# Removing cuda-libraries-dev-11-0 (11.0.3-1) ...
# Removing cuda-cupti-dev-11-0 (11.0.221-1) ...
# Removing cuda-cupti-11-0 (11.0.221-1) ...
# Removing cuda-libraries-11-0 (11.0.3-1) ...
# Removing cuda-libraries-dev-11-1 (11.1.1-1) ...
# Removing cuda-documentation-11-1 (11.1.105-1) ...
# Removing cuda-samples-11-1 (11.1.105-1) ...
# Removing cuda-libraries-11-1 (11.1.1-1) ...
# Removing cuda-cufft-dev-10-0 (10.0.130-1) ...
# Removing cuda-cufft-10-0 (10.0.130-1) ...
# Removing cuda-libraries-dev-10-1 (10.1.243-1) ...
# Removing cuda-documentation-10-1 (10.1.243-1) ...
# Removing cuda-samples-10-1 (10.1.243-1) ...
# Removing cuda-cufft-dev-10-1 (10.1.243-1) ...
# Removing cuda-cufft-10-1 (10.1.243-1) ...
# Removing cuda-gdb-10-0 (10.0.130-1) ...
# Removing cuda-cuobjdump-10-0 (10.0.130-1) ...
# Removing cuda-gdb-10-1 (10.1.243-1) ...
# Removing cuda-cuobjdump-10-1 (10.1.243-1) ...
# Removing cuda-gdb-11-0 (11.0.221-1) ...
# Removing cuda-cuobjdump-11-0 (11.0.221-1) ...
# Removing cuda-gdb-11-1 (11.1.105-1) ...
# Removing cuda-cuobjdump-11-1 (11.1.74-1) ...
# Removing cuda-cupti-dev-11-1 (11.1.105-1) ...
# Removing cuda-cupti-11-1 (11.1.105-1) ...
# Removing cuda-curand-dev-10-0 (10.0.130-1) ...
# Removing cuda-curand-10-0 (10.0.130-1) ...
# Removing cuda-curand-dev-10-1 (10.1.243-1) ...
# Removing cuda-curand-10-1 (10.1.243-1) ...
# Removing cuda-cusolver-dev-10-0 (10.0.130-1) ...
# Removing cuda-cusolver-10-0 (10.0.130-1) ...
# Removing cuda-cusolver-dev-10-1 (10.1.243-1) ...
# Removing cuda-cusolver-10-1 (10.1.243-1) ...
# Removing cuda-cusparse-dev-10-0 (10.0.130-1) ...
# Removing cuda-cusparse-10-0 (10.0.130-1) ...
# Removing cuda-cusparse-dev-10-1 (10.1.243-1) ...
# Removing cuda-cusparse-10-1 (10.1.243-1) ...
# Removing cuda-documentation-11-0 (11.0.228-1) ...
# Removing cuda-driver-dev-10-0 (10.0.130-1) ...
# Removing cuda-samples-11-0 (11.0.221-1) ...
# Removing cuda-drivers (515.65.01-1) ...
# Removing cuda-drivers-515 (515.65.01-1) ...
# Removing cuda-gpu-library-advisor-10-0 (10.0.130-1) ...
# Removing cuda-gpu-library-advisor-10-1 (10.1.243-1) ...
# Removing cuda-nvtx-10-0 (10.0.130-1) ...
# Removing cuda-nvrtc-dev-10-0 (10.0.130-1) ...
# Removing cuda-nvrtc-10-0 (10.0.130-1) ...
# Removing cuda-nsight-compute-10-1 (10.1.243-1) ...
# Removing cuda-nvgraph-dev-10-1 (10.1.243-1) ...
# Removing cuda-memcheck-10-0 (10.0.130-1) ...
# Removing cuda-memcheck-10-1 (10.1.243-1) ...
# Removing cuda-memcheck-11-0 (11.0.221-1) ...
# Removing cuda-memcheck-11-1 (11.1.105-1) ...
# Removing cuda-nvcc-10-0 (10.0.130-1) ...
# Removing cuda-misc-headers-10-0 (10.0.130-1) ...
# Removing cuda-nvcc-10-1 (10.1.243-1) ...
# Removing cuda-misc-headers-10-1 (10.1.243-1) ...
# Removing cuda-npp-dev-10-0 (10.0.130-1) ...
# Removing cuda-npp-10-0 (10.0.130-1) ...
# Removing cuda-npp-dev-10-1 (10.1.243-1) ...
# Removing cuda-npp-10-1 (10.1.243-1) ...
# Removing cuda-nsight-10-0 (10.0.130-1) ...
# Removing cuda-nsight-10-1 (10.1.243-1) ...
# Removing cuda-nsight-11-0 (11.0.221-1) ...
# Removing cuda-nsight-11-1 (11.1.105-1) ...
# Removing cuda-nsight-compute-10-0 (10.0.130-1) ...
# Removing cuda-nsight-compute-11-0 (11.0.3-1) ...
# Removing cuda-nsight-compute-11-1 (11.1.1-1) ...
# Removing cuda-nsight-systems-10-1 (10.1.243-1) ...
# Removing cuda-nsight-systems-11-0 (11.0.3-1) ...
# Removing cuda-nsight-systems-11-1 (11.1.1-1) ...
# Removing cuda-nvcc-11-0 (11.0.221-1) ...
# Removing cuda-nvdisasm-10-0 (10.0.130-1) ...
# Removing cuda-nvdisasm-10-1 (10.1.243-1) ...
# Removing cuda-nvdisasm-11-0 (11.0.221-1) ...
# Removing cuda-nvdisasm-11-1 (11.1.74-1) ...
# Removing cuda-nvgraph-dev-10-0 (10.0.130-1) ...
# Removing cuda-nvgraph-10-0 (10.0.130-1) ...
# Removing cuda-nvgraph-10-1 (10.1.243-1) ...
# Removing cuda-nvjpeg-dev-10-0 (10.0.130.1-1) ...
# Removing cuda-nvjpeg-10-0 (10.0.130.1-1) ...
# Removing cuda-nvjpeg-dev-10-1 (10.1.243-1) ...
# Removing cuda-nvjpeg-10-1 (10.1.243-1) ...
# Removing cuda-nvml-dev-10-0 (10.0.130-1) ...
# Removing cuda-nvml-dev-10-1 (10.1.243-1) ...
# Removing cuda-nvml-dev-11-0 (11.0.167-1) ...
# Removing cuda-nvml-dev-11-1 (11.1.74-1) ...
# Removing cuda-nvprof-10-0 (10.0.130-1) ...
# Removing cuda-nvprof-10-1 (10.1.243-1) ...
# Removing cuda-nvprof-11-0 (11.0.221-1) ...
# Removing cuda-nvprof-11-1 (11.1.105-1) ...
# Removing cuda-nvprune-10-0 (10.0.130-1) ...
# Removing cuda-nvprune-10-1 (10.1.243-1) ...
# Removing cuda-nvprune-11-0 (11.0.221-1) ...
# Removing cuda-nvprune-11-1 (11.1.74-1) ...
# Removing cuda-nvrtc-dev-10-1 (10.1.243-1) ...
# Removing cuda-nvrtc-10-1 (10.1.243-1) ...
# Removing cuda-nvrtc-dev-11-0 (11.0.221-1) ...
# Removing cuda-nvrtc-11-0 (11.0.221-1) ...
# Removing cuda-nvrtc-dev-11-1 (11.1.105-1) ...
# Removing cuda-nvrtc-11-1 (11.1.105-1) ...
# Removing cuda-nvtx-10-1 (10.1.243-1) ...
# Removing cuda-nvtx-11-0 (11.0.167-1) ...
# Removing cuda-nvtx-11-1 (11.1.74-1) ...
# Removing cuda-nvvp-10-0 (10.0.130-1) ...
# Removing cuda-nvvp-10-1 (10.1.243-1) ...
# Removing cuda-nvvp-11-0 (11.0.221-1) ...
# Removing cuda-nvvp-11-1 (11.1.105-1) ...
# Removing cuda-sanitizer-11-0 (11.0.221-1) ...
# Removing cuda-sanitizer-11-1 (11.1.105-1) ...
# Removing cuda-sanitizer-api-10-1 (10.1.243-1) ...
# Removing libcublas-dev (10.2.1.243-1) ...
# Removing libcublas10 (10.2.1.243-1) ...
# Removing cuda-nvcc-11-7 (11.7.99-1) ...
# Removing cuda-cudart-dev-11-7 (11.7.99-1) ...
# Removing cuda-cccl-11-7 (11.7.91-1) ...
# Removing cuda-cudart-11-7 (11.7.99-1) ...
# Removing cuda-driver-dev-11-7 (11.7.99-1) ...
# Removing cuda-toolkit-11-7-config-common (11.7.99-1) ...
# Removing alternatives
# Removing cuda-toolkit-11-config-common (11.7.99-1) ...
# Removing cuda-toolkit-config-common (11.7.99-1) ...
# Removing cuda-cudart-dev-10-1 (10.1.243-1) ...
# Removing cuda-cudart-10-1 (10.1.243-1) ...
# Removing cuda-cudart-dev-11-0 (11.0.221-1) ...
# Removing cuda-cudart-11-0 (11.0.221-1) ...
# Removing cuda-nvcc-11-1 (11.1.105-1) ...
# dpkg: warning: while removing cuda-nvcc-11-1, directory '/usr/local/cuda-11.1/bin' not empty so not removed
# Removing cuda-cudart-dev-11-1 (11.1.74-1) ...
# Removing cuda-cudart-11-1 (11.1.74-1) ...
# Removing cuda-driver-dev-10-1 (10.1.243-1) ...
# Removing cuda-driver-dev-11-0 (11.0.221-1) ...
# Removing cuda-driver-dev-11-1 (11.1.74-1) ...
# Removing cuda-license-10-0 (10.0.130-1) ...
# Removing cuda-license-10-1 (10.1.243-1) ...
# Setting up libcufft9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcusparse9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libthrust-dev (1.9.1~9.1.85-3ubuntu1) ...
# Setting up libvdpau-dev:amd64 (1.3-0ubuntu0~gpu18.04.2) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up gcc-6-base:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libcuinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libaccinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcurand9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvrtc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppitc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppif9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up gds-tools-11-7 (1.3.1.18-1) ...
# Setting up libnvvm3:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcublas9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up cpp-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up libcufftw9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcudart9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppim9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up libcusolver9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvblas9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppidei9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u342-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libnppial9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up nvidia-profiler (9.1.85-3ubuntu1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libasan3:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libgcc-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libstdc++-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libnppicom9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppisu9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnpps9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppicc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up libnppist9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libnppig9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvgraph9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up gcc-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up g++-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u342-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up nvidia-visual-profiler (9.1.85-3ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...

# %%
# !apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be REMOVED:
#   default-jre dkms fonts-dejavu-extra freeglut3 freeglut3-dev g++-6
#   gds-tools-11-7 keyboard-configuration libaccinj64-9.1 libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libcublas-dev-11-0 libcublas9.1 libcudart9.1 libcufft-11-0 libcufft-11-1
#   libcufft-dev-11-0 libcufft-dev-11-1 libcufft9.1 libcufftw9.1 libcuinj64-9.1
#   libcurand-11-0 libcurand-11-1 libcurand-dev-11-0 libcurand-dev-11-1
#   libcurand9.1 libcusolver-11-0 libcusolver-11-1 libcusolver-dev-11-0
#   libcusolver-dev-11-1 libcusolver9.1 libcusparse-11-0 libcusparse-dev-11-0
#   libcusparse9.1 libdevmapper1.02.1 libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libidn11 libip4tc0 libjansson4 libnpp-11-0
#   libnpp-dev-11-0 libnppc9.1 libnppial9.1 libnppicc9.1 libnppicom9.1
#   libnppidei9.1 libnppif9.1 libnppig9.1 libnppim9.1 libnppist9.1 libnppisu9.1
#   libnppitc9.1 libnpps9.1 libnvblas9.1 libnvgraph9.1 libnvidia-cfg1-515
#   libnvidia-common-460 libnvidia-common-515 libnvidia-decode-515
#   libnvidia-encode-515 libnvidia-extra-515 libnvidia-fbc1-515 libnvidia-gl-515
#   libnvjpeg-11-0 libnvjpeg-11-1 libnvjpeg-dev-11-0 libnvjpeg-dev-11-1
#   libnvrtc9.1 libnvtoolsext1 libnvvm3 libpam-systemd libpolkit-agent-1-0
#   libpolkit-backend-1-0 libpolkit-gobject-1-0 libthrust-dev libvdpau-dev
#   libxfont2 libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0
#   nsight-compute-2020.2.1 nsight-compute-2022.2.1 nsight-systems-2020.3.2
#   nsight-systems-2020.3.4 nsight-systems-2022.1.3 nvidia-compute-utils-515
#   nvidia-dkms-515 nvidia-driver-515 nvidia-kernel-common-515
#   nvidia-kernel-source-515 nvidia-modprobe nvidia-profiler nvidia-settings
#   nvidia-utils-515 nvidia-visual-profiler openjdk-11-jre openjdk-8-jre
#   policykit-1 policykit-1-gnome python3-xkit screen-resolution-extra systemd
#   systemd-sysv udev x11-xkb-utils xserver-common xserver-xorg-core-hwe-18.04
#   xserver-xorg-video-nvidia-515
# 0 upgraded, 0 newly installed, 117 to remove and 20 not upgraded.
# After this operation, 7,737 MB disk space will be freed.
# (Reading database ... 122818 files and directories currently installed.)
# Removing default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Removing nvidia-driver-515 (515.65.01-0ubuntu1) ...
# Removing nvidia-dkms-515 (515.65.01-0ubuntu1) ...
# Removing all DKMS Modules
# Done.
# Removing dkms (2.3-3ubuntu9.7) ...
# Removing fonts-dejavu-extra (2.37-1) ...
# Removing freeglut3-dev:amd64 (2.8.1-3) ...
# Removing freeglut3:amd64 (2.8.1-3) ...
# Removing g++-6 (6.5.0-2ubuntu1~18.04) ...
# Removing gds-tools-11-7 (1.3.1.18-1) ...
# make: Entering directory '/usr/local/cuda-11.7/gds/samples'
# rm -f cufile_sample_001 cufile_sample_001.o cufile_sample_002 cufile_sample_002.o cufile_sample_003 cufile_sample_003.o cufile_sample_004 cufile_sample_004.o cufile_sample_005 cufile_sample_005.o cufile_sample_006 cufile_sample_006.o cufile_sample_007 cufile_sample_007.o cufile_sample_008 cufile_sample_008.o cufile_sample_009 cufile_sample_009.o cufile_sample_010 cufile_sample_010.o cufile_sample_011 cufile_sample_011.o cufile_sample_012 cufile_sample_012.o cufile_sample_013 cufile_sample_013.o cufile_sample_014 cufile_sample_014.o cufile_sample_015 cufile_sample_015.o cufile_sample_016.o cufile_sample_016 cufile_sample_017.o cufile_sample_017 cufile_sample_018.o cufile_sample_019.o cufile_sample_018 cufile_sample_001_static cufile_sample_002_static cufile_sample_003_static cufile_sample_004_static cufile_sample_005_static cufile_sample_006_static cufile_sample_007_static cufile_sample_008_static cufile_sample_009_static cufile_sample_010_static cufile_sample_011_static cufile_sample_012_static cufile_sample_013_static cufile_sample_014_static cufile_sample_015_static cufile_sample_016_static cufile_sample_017_static cufile_sample_018_static cufile_sample_019_static cufile_sample_019 cufile_sample_020_static cufile_sample_020 cufile_sample_021 cufile_sample_022
# make: Leaving directory '/usr/local/cuda-11.7/gds/samples'
# Removing xserver-xorg-video-nvidia-515 (515.65.01-0ubuntu1) ...
# Removing xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.7) ...
# Removing keyboard-configuration (1.178ubuntu2.9) ...
# Removing libaccinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing nvidia-settings (515.65.01-0ubuntu1) ...
# Removing screen-resolution-extra (0.17.3) ...
# Removing policykit-1-gnome (0.105-6ubuntu2) ...
# Removing policykit-1 (0.105-20ubuntu0.18.04.6) ...
# Removing libpam-systemd:amd64 (237-3ubuntu10.56) ...
# Removing systemd-sysv (237-3ubuntu10.56) ...
# Removing systemd (237-3ubuntu10.56) ...
# Removing libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.2) ...
# Removing libargon2-0:amd64 (0~20161029-1.1) ...
# Removing nvidia-visual-profiler (9.1.85-3ubuntu1) ...
# Removing openjdk-8-jre:amd64 (8u342-b07-0ubuntu1~18.04) ...
# Removing openjdk-11-jre:amd64 (11.0.16+8-0ubuntu1~18.04) ...
# Removing libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Removing libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Removing libcap2:amd64 (1:2.25-1.2) ...
# Removing libcublas-dev-11-0 (11.2.0.252-1) ...
# Removing libnvgraph9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnvblas9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcublas9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcudart9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcufft-dev-11-0 (10.2.1.245-1) ...
# Removing libcufft-11-0 (10.2.1.245-1) ...
# Removing libcufft-dev-11-1 (10.3.0.105-1) ...
# Removing libcufft-11-1 (10.3.0.105-1) ...
# Removing libcufftw9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcufft9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing nvidia-profiler (9.1.85-3ubuntu1) ...
# Removing libcuinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcurand-dev-11-0 (10.2.1.245-1) ...
# Removing libcurand-11-0 (10.2.1.245-1) ...
# Removing libcurand-dev-11-1 (10.2.2.105-1) ...
# Removing libcurand-11-1 (10.2.2.105-1) ...
# Removing libcurand9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcusolver-dev-11-0 (10.6.0.245-1) ...
# Removing libcusolver-11-0 (10.6.0.245-1) ...
# Removing libcusolver-dev-11-1 (11.0.1.105-1) ...
# Removing libcusolver-11-1 (11.0.1.105-1) ...
# Removing libcusolver9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libcusparse-dev-11-0 (11.1.1.245-1) ...
# Removing libcusparse-11-0 (11.1.1.245-1) ...
# Removing libcusparse9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Removing libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Removing libgail18:amd64 (2.24.32-1ubuntu1) ...
# Removing libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Removing libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Removing libgtk2.0-common (2.24.32-1ubuntu1) ...
# Removing libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Removing libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Removing libjansson4:amd64 (2.11-1) ...
# Removing libnpp-dev-11-0 (11.1.0.245-1) ...
# Removing libnpp-11-0 (11.1.0.245-1) ...
# Removing libnppial9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnpps9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppicc9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppicom9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppidei9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppif9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppig9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppim9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppist9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppisu9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnppitc9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnvidia-cfg1-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvidia-common-460 (460.106.00-0ubuntu1) ...
# Removing libnvidia-gl-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvidia-common-515 (515.65.01-0ubuntu1) ...
# Removing libnvidia-encode-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvidia-decode-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvidia-extra-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvidia-fbc1-515:amd64 (515.65.01-0ubuntu1) ...
# Removing libnvjpeg-dev-11-0 (11.1.1.245-1) ...
# Removing libnvjpeg-11-0 (11.1.1.245-1) ...
# Removing libnvjpeg-dev-11-1 (11.3.0.105-1) ...
# Removing libnvjpeg-11-1 (11.3.0.105-1) ...
# Removing libnvrtc9.1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Removing libnvvm3:amd64 (9.1.85-3ubuntu1) ...
# Removing libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.6) ...
# Removing libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.6) ...
# Removing libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.6) ...
# Removing libthrust-dev (1.9.1~9.1.85-3ubuntu1) ...
# Removing libvdpau-dev:amd64 (1.3-0ubuntu0~gpu18.04.2) ...
# Removing libxfont2:amd64 (1:2.0.3-1) ...
# Removing libxi-dev:amd64 (2:1.7.9-1) ...
# Removing xserver-common (2:1.19.6-1ubuntu4.11) ...
# Removing x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Removing libxkbfile1:amd64 (1:1.0.9-2) ...
# Removing libxmu-dev:amd64 (2:1.1.2-2) ...
# Removing libxmu-headers (2:1.1.2-2) ...
# Removing libxnvctrl0:amd64 (515.65.01-0ubuntu1) ...
# Removing nsight-compute-2020.2.1 (2020.2.1.8-1) ...
# Removing nsight-compute-2022.2.1 (2022.2.1.3-1) ...
# Removing nsight-systems-2020.3.2 (2020.3.2.6-87e152c) ...
# Removing nsight-systems-2020.3.4 (2020.3.4.32-52657a0) ...
# update-alternatives: removing manually selected alternative - switching nsys to auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2022.1.3/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: removing manually selected alternative - switching nsight-sys to auto mode
# update-alternatives: removing manually selected alternative - switching nsys-ui to auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2022.1.3/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Removing nsight-systems-2022.1.3 (2022.1.3.3-1c7b5f7) ...
# dpkg: warning: while removing nsight-systems-2022.1.3, directory '/usr/local/bin' not empty so not removed
# dpkg: warning: while removing nsight-systems-2022.1.3, directory '/opt' not empty so not removed
# Removing nvidia-compute-utils-515 (515.65.01-0ubuntu1) ...
# Removing nvidia-kernel-common-515 (515.65.01-0ubuntu1) ...
# Removing nvidia-kernel-source-515 (515.65.01-0ubuntu1) ...
# Removing nvidia-modprobe (515.65.01-0ubuntu1) ...
# Removing nvidia-utils-515 (515.65.01-0ubuntu1) ...
# Removing python3-xkit (0.5.0ubuntu2) ...
# Removing udev (237-3ubuntu10.56) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# Removing libnppc9.1:amd64 (9.1.85-3ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.3) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %%
# !apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 261 kB in 2s (128 kB/s)
# Reading package lists... Done

# %% [markdown]
# # Install CUDA and CUDA dev and Toolkit

# %%
# !apt-get install cuda nvidia-cuda-dev nvidia-cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  cuda-drivers : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  libcuda1-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-396-dev : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
#  nvidia-cuda-dev : Depends: libaccinj64-9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcudart9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcuinj64-9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnvrtc9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnvtoolsext1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnvvm3 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcublas9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnvblas9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcufft9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcufftw9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcurand9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcusolver9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libcusparse9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppc9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppial9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppicc9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppicom9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppidei9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppif9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppig9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppim9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppist9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppisu9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnppitc9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnpps9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libnvgraph9.1 (= 9.1.85-3ubuntu1) but it is not going to be installed
#                    Depends: libthrust-dev but it is not going to be installed
#                    Recommends: libcuda1 (>= 387.26) or
#                                libcuda-9.1-1
#                    Recommends: libvdpau-dev but it is not going to be installed
#                    Recommends: libnvcuvid1 but it is not installable
#  nvidia-cuda-toolkit : Depends: nvidia-profiler (= 9.1.85-3ubuntu1) but it is not going to be installed
#                        Depends: g++-6 but it is not going to be installed or
#                                 clang-4.0 but it is not going to be installed or
#                                 clang-3.9 but it is not going to be installed or
#                                 clang-3.8 but it is not installable or
#                                 clang (< 1:5~) but 1:6.0-41~exp5~ubuntu1 is to be installed or
#                                 g++-5 but it is not going to be installed or
#                                 g++-4.9 but it is not installable or
#                                 g++-4.8 but it is not going to be installed
#                        Depends: libnvvm3 (>= 7.0) but it is not going to be installed
#                        Recommends: nvidia-cuda-doc (= 9.1.85-3ubuntu1) but it is not going to be installed
#                        Recommends: nvidia-cuda-gdb (= 9.1.85-3ubuntu1) but it is not going to be installed
#                        Recommends: nvidia-visual-profiler (= 9.1.85-3ubuntu1) but it is not going to be installed
#  nvidia-opencl-icd-396 : Depends: nvidia-396 (>= 396.26) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %% [markdown]
# # Install CUDA Toolkit

# %%
# !apt-get install nvidia-cuda-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Recommended packages:
#   libnvcuvid1
# The following NEW packages will be installed:
#   nvidia-cuda-dev
# 0 upgraded, 1 newly installed, 0 to remove and 26 not upgraded.
# 108 not fully installed or removed.
# Need to get 263 MB of archives.
# After this operation, 734 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 nvidia-cuda-dev amd64 9.1.85-3ubuntu1 [263 MB]
# Fetched 263 MB in 4s (73.0 MB/s)
# (Reading database ... 167197 files and directories currently installed.)
# Preparing to unpack .../nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev (9.1.85-3ubuntu1) ...
# dpkg: error processing archive /var/cache/apt/archives/nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb (--unpack):
#  trying to overwrite '/usr/include/cublas.h', which is also in package libcublas-dev 10.2.1.243-1
# dpkg-deb: error: paste subprocess was killed by signal (Broken pipe)
# Errors were encountered while processing:
#  /var/cache/apt/archives/nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)

# %%
# !apt-get install nvidia-cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# nvidia-cuda-toolkit is already the newest version (9.1.85-3ubuntu1).
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  nvidia-cuda-toolkit : Depends: nvidia-cuda-dev (= 9.1.85-3ubuntu1) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  nvidia-cuda-toolkit : Depends: nvidia-cuda-dev (= 9.1.85-3ubuntu1) but it is not installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !apt --fix-broken install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Correcting dependencies... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   nvidia-cuda-dev
# Recommended packages:
#   libnvcuvid1
# The following NEW packages will be installed:
#   nvidia-cuda-dev
# 0 upgraded, 1 newly installed, 0 to remove and 26 not upgraded.
# 108 not fully installed or removed.
# Need to get 263 MB of archives.
# After this operation, 734 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 nvidia-cuda-dev amd64 9.1.85-3ubuntu1 [263 MB]
# Fetched 263 MB in 4s (72.5 MB/s)
# (Reading database ... 167197 files and directories currently installed.)
# Preparing to unpack .../nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev (9.1.85-3ubuntu1) ...
# dpkg: error processing archive /var/cache/apt/archives/nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb (--unpack):
#  trying to overwrite '/usr/include/cublas.h', which is also in package libcublas-dev 10.2.1.243-1
# dpkg-deb: error: paste subprocess was killed by signal (Broken pipe)
# Errors were encountered while processing:
#  /var/cache/apt/archives/nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)

# %%
# !apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  nvidia-cuda-toolkit : Depends: nvidia-cuda-dev (= 9.1.85-3ubuntu1) but it is not installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !apt update && sudo apt full-upgrade
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 261 kB in 2s (115 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 26 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  nvidia-cuda-toolkit : Depends: nvidia-cuda-dev (= 9.1.85-3ubuntu1) but it is not installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !dpkg -l | grep -e cuda-.*9-1 | awk '{print $2}' | xargs -n1  dpkg --purge --force-all && apt-get remove nvidia-cuda-toolkit
# Out:
# dpkg: cuda-cudart-11-7: dependency problems, but removing anyway as you requested:
#  cuda-cudart-dev-11-7 depends on cuda-cudart-11-7 (>= 11.7.99).
#  cuda-libraries-11-7 depends on cuda-cudart-11-7 (>= 11.7.99).
#
# (Reading database ... 167197 files and directories currently installed.)
# Removing cuda-cudart-11-7 (11.7.99-1) ...
# dpkg: cuda-cudart-dev-11-7: dependency problems, but removing anyway as you requested:
#  cuda-nvcc-11-7 depends on cuda-cudart-dev-11-7.
#  cuda-libraries-dev-11-7 depends on cuda-cudart-dev-11-7 (>= 11.7.99).
#  cuda-cupti-11-7 depends on cuda-cudart-dev-11-7.
#
# (Reading database ... 167189 files and directories currently installed.)
# Removing cuda-cudart-dev-11-7 (11.7.99-1) ...
# dpkg: cuda-driver-dev-11-7: dependency problems, but removing anyway as you requested:
#  cuda-libraries-dev-11-7 depends on cuda-driver-dev-11-7 (>= 11.7.99); however:
#   Package cuda-driver-dev-11-7 is to be removed.
#
# (Reading database ... 167081 files and directories currently installed.)
# Removing cuda-driver-dev-11-7 (11.7.99-1) ...
# dpkg: cuda-nvcc-11-7: dependency problems, but removing anyway as you requested:
#  cuda-compiler-11-7 depends on cuda-nvcc-11-7 (>= 11.7.99); however:
#   Package cuda-nvcc-11-7 is to be removed.
#  cuda-cupti-11-7 depends on cuda-nvcc-11-7; however:
#   Package cuda-nvcc-11-7 is to be removed.
#
# (Reading database ... 167076 files and directories currently installed.)
# Removing cuda-nvcc-11-7 (11.7.99-1) ...
# dpkg: cuda-nvrtc-11-7: dependency problems, but removing anyway as you requested:
#  cuda-nvrtc-dev-11-7 depends on cuda-nvrtc-11-7 (>= 11.7.99).
#  cuda-libraries-11-7 depends on cuda-nvrtc-11-7 (>= 11.7.99); however:
#   Package cuda-nvrtc-11-7 is to be removed.
#
# (Reading database ... 167003 files and directories currently installed.)
# Removing cuda-nvrtc-11-7 (11.7.99-1) ...
# dpkg: cuda-nvrtc-dev-11-7: dependency problems, but removing anyway as you requested:
#  cuda-libraries-dev-11-7 depends on cuda-nvrtc-dev-11-7 (>= 11.7.99); however:
#   Package cuda-nvrtc-dev-11-7 is to be removed.
#
# (Reading database ... 166996 files and directories currently installed.)
# Removing cuda-nvrtc-dev-11-7 (11.7.99-1) ...
# dpkg: cuda-toolkit-11-7-config-common: dependency problems, but removing anyway as you requested:
#  libcufile-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcublas-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libnvjpeg-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libnpp-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcusolver-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcusparse-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcufft-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#  libcurand-11-7 depends on cuda-toolkit-11-7-config-common; however:
#   Package cuda-toolkit-11-7-config-common is to be removed.
#
# (Reading database ... 166986 files and directories currently installed.)
# Removing cuda-toolkit-11-7-config-common (11.7.99-1) ...
# Removing alternatives
# Purging configuration files for cuda-toolkit-11-7-config-common (11.7.99-1) ...
# Removing alternatives
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# dpkg: cuda-toolkit-11-config-common: dependency problems, but removing anyway as you requested:
#  libcufile-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcublas-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnvjpeg-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnpp-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusolver-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusparse-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcufft-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcurand-11-7 depends on cuda-toolkit-11-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-11-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#
# (Reading database ... 166983 files and directories currently installed.)
# Removing cuda-toolkit-11-config-common (11.7.99-1) ...
# Purging configuration files for cuda-toolkit-11-config-common (11.7.99-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# dpkg: cuda-toolkit-config-common: dependency problems, but removing anyway as you requested:
#  libcufile-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcublas-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnvjpeg-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libnpp-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusolver-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcusparse-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcufft-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#  libcurand-11-7 depends on cuda-toolkit-config-common | cuda-cudart-11-2; however:
#   Package cuda-toolkit-config-common is to be removed.
#   Package cuda-cudart-11-2 is not installed.
#
# (Reading database ... 166979 files and directories currently installed.)
# Removing cuda-toolkit-config-common (11.7.99-1) ...
# Purging configuration files for cuda-toolkit-config-common (11.7.99-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  cuda-compiler-11-7 : Depends: cuda-nvcc-11-7 (>= 11.7.99) but it is not going to be installed
#  cuda-cupti-11-7 : Depends: cuda-cudart-dev-11-7 but it is not going to be installed
#                    Depends: cuda-nvcc-11-7 but it is not going to be installed
#  cuda-libraries-11-7 : Depends: cuda-cudart-11-7 (>= 11.7.99) but it is not going to be installed
#                        Depends: cuda-nvrtc-11-7 (>= 11.7.99) but it is not going to be installed
#  cuda-libraries-dev-11-7 : Depends: cuda-cudart-dev-11-7 (>= 11.7.99) but it is not going to be installed
#                            Depends: cuda-driver-dev-11-7 (>= 11.7.99) but it is not going to be installed
#                            Depends: cuda-nvrtc-dev-11-7 (>= 11.7.99) but it is not going to be installed
#  libcublas-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libcufft-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                           cuda-cudart-11-2 but it is not going to be installed
#                  Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                           cuda-cudart-11-2 but it is not going to be installed
#                  Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libcufile-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libcurand-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libcusolver-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                              cuda-cudart-11-2 but it is not going to be installed
#                     Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                              cuda-cudart-11-2 but it is not going to be installed
#                     Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libcusparse-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                              cuda-cudart-11-2 but it is not going to be installed
#                     Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                              cuda-cudart-11-2 but it is not going to be installed
#                     Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libnpp-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                         cuda-cudart-11-2 but it is not going to be installed
#                Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                         cuda-cudart-11-2 but it is not going to be installed
#                Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
#  libnvjpeg-11-7 : Depends: cuda-toolkit-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-config-common but it is not going to be installed or
#                            cuda-cudart-11-2 but it is not going to be installed
#                   Depends: cuda-toolkit-11-7-config-common but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !dpkg --configure nvidia-cuda-dev && dpkg --configure nvidia-cuda-toolkit
# Out:
# dpkg: error processing package nvidia-cuda-dev (--configure):
#  no package named 'nvidia-cuda-dev' is installed, cannot configure
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Errors were encountered while processing:
#  nvidia-cuda-dev

# %%
# !cmake --version
# Out:
# cmake version 3.22.6
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %% [markdown]
# # Colab have install cmake , may not re-install Cmake
#
#
#
#
# *  CMake is an open-source, cross-platform family of tools
# *  designed to build, test and package software.
# *  Used to control the software compilation process.
# *  by using simple platform and compiler independent configuration files,
# *  generate native makefiles and workspaces that can be used in the compiler environment of your choice.

# %%
# !apt-get install cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.9.1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
# !ls /usr/bin/g*
# Out:
# /usr/bin/g++		     /usr/bin/genfio
# /usr/bin/g++-6		     /usr/bin/genrb
# /usr/bin/g++-7		     /usr/bin/geos-config
# /usr/bin/gapplication	     /usr/bin/geqn
# /usr/bin/gc		     /usr/bin/getconf
# /usr/bin/gcc		     /usr/bin/getent
# /usr/bin/gcc-6		     /usr/bin/getopt
# /usr/bin/gcc-7		     /usr/bin/gfortran
# /usr/bin/gcc-ar		     /usr/bin/gfortran-7
# /usr/bin/gcc-ar-6	     /usr/bin/gio
# /usr/bin/gcc-ar-7	     /usr/bin/gio-querymodules
# /usr/bin/gcc-nm		     /usr/bin/git
# /usr/bin/gcc-nm-6	     /usr/bin/git-lfs
# /usr/bin/gcc-nm-7	     /usr/bin/git-receive-pack
# /usr/bin/gcc-ranlib	     /usr/bin/git-shell
# /usr/bin/gcc-ranlib-6	     /usr/bin/git-upload-archive
# /usr/bin/gcc-ranlib-7	     /usr/bin/git-upload-pack
# /usr/bin/gcov		     /usr/bin/glib-compile-resources
# /usr/bin/gcov-6		     /usr/bin/glib-compile-schemas
# /usr/bin/gcov-7		     /usr/bin/glib-genmarshal
# /usr/bin/gcov-dump	     /usr/bin/glib-gettextize
# /usr/bin/gcov-dump-6	     /usr/bin/glib-mkenums
# /usr/bin/gcov-dump-7	     /usr/bin/gml2gv
# /usr/bin/gcov-tool	     /usr/bin/gnmanalyse
# /usr/bin/gcov-tool-6	     /usr/bin/gnmmanage
# /usr/bin/gcov-tool-7	     /usr/bin/gobject-query
# /usr/bin/gcps2vec.py	     /usr/bin/gold
# /usr/bin/gcps2wld.py	     /usr/bin/google-pprof
# /usr/bin/gdal2tiles.py	     /usr/bin/gpasswd
# /usr/bin/gdal2xyz.py	     /usr/bin/gpg
# /usr/bin/gdaladdo	     /usr/bin/gpg2
# /usr/bin/gdal_auth.py	     /usr/bin/gpg-agent
# /usr/bin/gdalbuildvrt	     /usr/bin/gpgconf
# /usr/bin/gdal_calc.py	     /usr/bin/gpg-connect-agent
# /usr/bin/gdalchksum.py	     /usr/bin/gpg-error
# /usr/bin/gdalcompare.py      /usr/bin/gpg-error-config
# /usr/bin/gdal-config	     /usr/bin/gpgparsemail
# /usr/bin/gdal_contour	     /usr/bin/gpgsm
# /usr/bin/gdaldem	     /usr/bin/gpgsplit
# /usr/bin/gdal_edit.py	     /usr/bin/gpgv
# /usr/bin/gdalenhance	     /usr/bin/gpg-wks-server
# /usr/bin/gdal_fillnodata.py  /usr/bin/gpg-zip
# /usr/bin/gdal_grid	     /usr/bin/gpic
# /usr/bin/gdalident.py	     /usr/bin/gprof
# /usr/bin/gdalimport.py	     /usr/bin/gpu-library-advisor
# /usr/bin/gdalinfo	     /usr/bin/graphml2gv
# /usr/bin/gdallocationinfo    /usr/bin/gresource
# /usr/bin/gdalmanage	     /usr/bin/groff
# /usr/bin/gdal_merge.py	     /usr/bin/grog
# /usr/bin/gdalmove.py	     /usr/bin/grops
# /usr/bin/gdal_pansharpen.py  /usr/bin/grotty
# /usr/bin/gdal_polygonize.py  /usr/bin/groups
# /usr/bin/gdal_proximity.py   /usr/bin/gsettings
# /usr/bin/gdal_rasterize      /usr/bin/gtbl
# /usr/bin/gdal_retile.py      /usr/bin/gtester
# /usr/bin/gdalserver	     /usr/bin/gtester-report
# /usr/bin/gdal_sieve.py	     /usr/bin/gtf
# /usr/bin/gdalsrsinfo	     /usr/bin/gtk-update-icon-cache
# /usr/bin/gdaltindex	     /usr/bin/gv2gml
# /usr/bin/gdaltransform	     /usr/bin/gv2gxl
# /usr/bin/gdal_translate      /usr/bin/gvcolor
# /usr/bin/gdalwarp	     /usr/bin/gvgen
# /usr/bin/gdbus		     /usr/bin/gvmap
# /usr/bin/gdbus-codegen	     /usr/bin/gvmap.sh
# /usr/bin/genbrk		     /usr/bin/gvpack
# /usr/bin/gencat		     /usr/bin/gvpr
# /usr/bin/gencfu		     /usr/bin/gxl2dot
# /usr/bin/gencnval	     /usr/bin/gxl2gv
# /usr/bin/gendict

# %%
! ln -s /usr/bin/gcc-6 /usr/local/cuda/bin/gcc
! ln -s /usr/bin/g++-6 /usr/local/cuda/bin/g++

# %% [markdown]
# # Upload the Repo

# %%
# !git clone https://github.com/chiyanglin-AStar/Cuda_Colab_study.git
# Out:
# Cloning into 'Cuda_Colab_study'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 96 (delta 44), reused 29 (delta 7), pack-reused 0
# Unpacking objects: 100% (96/96), done.

# %%
# !ls
# Out:
# Cuda_Colab_study  sample_data

# %%
# %cd Cuda_Colab_study/basic_tutorial
# Out:
# /content/Cuda_Colab_study/basic_tutorial

# %% [markdown]
# ref :

# %%
# %%writefile book.h
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #ifndef __BOOK_H__
# #define __BOOK_H__
# #include <stdio.h>
#
# static void HandleError( cudaError_t err,
#                          const char *file,
#                          int line ) {
#     if (err != cudaSuccess) {
#         printf( "%s in %s at line %d\n", cudaGetErrorString( err ),
#                 file, line );
#         exit( EXIT_FAILURE );
#     }
# }
# #define HANDLE_ERROR( err ) (HandleError( err, __FILE__, __LINE__ ))
#
#
# #define HANDLE_NULL( a ) {if (a == NULL) { \
#                             printf( "Host memory failed in %s at line %d\n", \
#                                     __FILE__, __LINE__ ); \
#                             exit( EXIT_FAILURE );}}
#
# template< typename T >
# void swap( T& a, T& b ) {
#     T t = a;
#     a = b;
#     b = t;
# }
#
#
# void* big_random_block( int size ) {
#     unsigned char *data = (unsigned char*)malloc( size );
#     HANDLE_NULL( data );
#     for (int i=0; i<size; i++)
#         data[i] = rand();
#
#     return data;
# }
#
# int* big_random_block_int( int size ) {
#     int *data = (int*)malloc( size * sizeof(int) );
#     HANDLE_NULL( data );
#     for (int i=0; i<size; i++)
#         data[i] = rand();
#
#     return data;
# }
#
#
# // a place for common kernels - starts here
#
# __device__ unsigned char value( float n1, float n2, int hue ) {
#     if (hue > 360)      hue -= 360;
#     else if (hue < 0)   hue += 360;
#
#     if (hue < 60)
#         return (unsigned char)(255 * (n1 + (n2-n1)*hue/60));
#     if (hue < 180)
#         return (unsigned char)(255 * n2);
#     if (hue < 240)
#         return (unsigned char)(255 * (n1 + (n2-n1)*(240-hue)/60));
#     return (unsigned char)(255 * n1);
# }
#
# __global__ void float_to_color( unsigned char *optr,
#                               const float *outSrc ) {
#     // map from threadIdx/BlockIdx to pixel position
#     int x = threadIdx.x + blockIdx.x * blockDim.x;
#     int y = threadIdx.y + blockIdx.y * blockDim.y;
#     int offset = x + y * blockDim.x * gridDim.x;
#
#     float l = outSrc[offset];
#     float s = 1;
#     int h = (180 + (int)(360.0f * outSrc[offset])) % 360;
#     float m1, m2;
#
#     if (l <= 0.5f)
#         m2 = l * (1 + s);
#     else
#         m2 = l + s - l * s;
#     m1 = 2 * l - m2;
#
#     optr[offset*4 + 0] = value( m1, m2, h+120 );
#     optr[offset*4 + 1] = value( m1, m2, h );
#     optr[offset*4 + 2] = value( m1, m2, h -120 );
#     optr[offset*4 + 3] = 255;
# }
#
# __global__ void float_to_color( uchar4 *optr,
#                               const float *outSrc ) {
#     // map from threadIdx/BlockIdx to pixel position
#     int x = threadIdx.x + blockIdx.x * blockDim.x;
#     int y = threadIdx.y + blockIdx.y * blockDim.y;
#     int offset = x + y * blockDim.x * gridDim.x;
#
#     float l = outSrc[offset];
#     float s = 1;
#     int h = (180 + (int)(360.0f * outSrc[offset])) % 360;
#     float m1, m2;
#
#     if (l <= 0.5f)
#         m2 = l * (1 + s);
#     else
#         m2 = l + s - l * s;
#     m1 = 2 * l - m2;
#
#     optr[offset].x = value( m1, m2, h+120 );
#     optr[offset].y = value( m1, m2, h );
#     optr[offset].z = value( m1, m2, h -120 );
#     optr[offset].w = 255;
# }
#
#
# #if _WIN32
#     //Windows threads.
#     #include <windows.h>
#
#     typedef HANDLE CUTThread;
#     typedef unsigned (WINAPI *CUT_THREADROUTINE)(void *);
#
#     #define CUT_THREADPROC unsigned WINAPI
#     #define  CUT_THREADEND return 0
#
# #else
#     //POSIX threads.
#     #include <pthread.h>
#
#     typedef pthread_t CUTThread;
#     typedef void *(*CUT_THREADROUTINE)(void *);
#
#     #define CUT_THREADPROC void
#     #define  CUT_THREADEND
# #endif
#
# //Create thread.
# CUTThread start_thread( CUT_THREADROUTINE, void *data );
#
# //Wait for thread to finish.
# void end_thread( CUTThread thread );
#
# //Destroy thread.
# void destroy_thread( CUTThread thread );
#
# //Wait for multiple threads.
# void wait_for_threads( const CUTThread *threads, int num );
#
# #if _WIN32
#     //Create thread
#     CUTThread start_thread(CUT_THREADROUTINE func, void *data){
#         return CreateThread(NULL, 0, (LPTHREAD_START_ROUTINE)func, data, 0, NULL);
#     }
#
#     //Wait for thread to finish
#     void end_thread(CUTThread thread){
#         WaitForSingleObject(thread, INFINITE);
#         CloseHandle(thread);
#     }
#
#     //Destroy thread
#     void destroy_thread( CUTThread thread ){
#         TerminateThread(thread, 0);
#         CloseHandle(thread);
#     }
#
#     //Wait for multiple threads
#     void wait_for_threads(const CUTThread * threads, int num){
#         WaitForMultipleObjects(num, threads, true, INFINITE);
#
#         for(int i = 0; i < num; i++)
#             CloseHandle(threads[i]);
#     }
#
# #else
#     //Create thread
#     CUTThread start_thread(CUT_THREADROUTINE func, void * data){
#         pthread_t thread;
#         pthread_create(&thread, NULL, func, data);
#         return thread;
#     }
#
#     //Wait for thread to finish
#     void end_thread(CUTThread thread){
#         pthread_join(thread, NULL);
#     }
#
#     //Destroy thread
#     void destroy_thread( CUTThread thread ){
#         pthread_cancel(thread);
#     }
#
#     //Wait for multiple threads
#     void wait_for_threads(const CUTThread * threads, int num){
#         for(int i = 0; i < num; i++)
#             end_thread( threads[i] );
#     }
#
# #endif
#
#
#
#
# #endif  // __BOOK_H__
# Out:
# Overwriting book.h

# %%
# %%writefile hello.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# int main( void ) {
#     printf( "Hello, World!\n" );
#     return 0;
# }
# Out:
# Writing hello.cu

# %%
# !nvcc hello.cu -o hello

# %%
# !rm hello

# %%
# !nvcc -arch=sm_75 -o hello hello.cu

# %%
# !ls
# Out:
# book.h	cuda_basic_tutorial.ipynb  hello  hello.cu

# %%
# !./hello
# Out:
# Hello, World!

# %%
# %%writefile simple_kernel.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# __global__ void kernel( void ) {
# }
#
# int main( void ) {
#     kernel<<<1,1>>>();
#     printf( "Hello, World!\n" );
#     return 0;
# }
# Out:
# Writing simple_kernel.cu

# %%
# !nvcc simple_kernel.cu

# %%
# !./a.out
# Out:
# Hello, World!

# %%
# %%writefile simple_kernel_para.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# __global__ void add( int a, int b, int *c ) {
#     *c = a + b;
# }
#
# int main( void ) {
#     int c;
#     int *dev_c;
#     HANDLE_ERROR( cudaMalloc( (void**)&dev_c, sizeof(int) ) );
#
#     add<<<1,1>>>( 2, 7, dev_c );
#
#     HANDLE_ERROR( cudaMemcpy( &c, dev_c, sizeof(int),
#                               cudaMemcpyDeviceToHost ) );
#     printf( "2 + 7 = %d\n", c );
#     HANDLE_ERROR( cudaFree( dev_c ) );
#
#     return 0;
# }
# Out:
# Writing simple_kernel_para.cu

# %%
# !nvcc simple_kernel_para.cu

# %%
# !./a.out
# Out:
# 2 + 7 = 9

# %%
# %%writefile simple_device_call.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# __device__ int addem( int a, int b ) {
#     return a + b;
# }
#
# __global__ void add( int a, int b, int *c ) {
#     *c = addem( a, b );
# }
#
# int main( void ) {
#     int c;
#     int *dev_c;
#     HANDLE_ERROR( cudaMalloc( (void**)&dev_c, sizeof(int) ) );
#
#     add<<<1,1>>>( 2, 7, dev_c );
#
#     HANDLE_ERROR( cudaMemcpy( &c, dev_c, sizeof(int),
#                               cudaMemcpyDeviceToHost ) );
#     printf( "2 + 7 = %d\n", c );
#     HANDLE_ERROR( cudaFree( dev_c ) );
#
#     return 0;
# }
# Out:
# Writing simple_device_call.cu

# %%
# !nvcc simple_device_call.cu

# %%
# !./a.out
# Out:
# 2 + 7 = 9

# %%
# %%writefile enum_gpu.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# int main( void ) {
#     cudaDeviceProp  prop;
#
#     int count;
#     HANDLE_ERROR( cudaGetDeviceCount( &count ) );
#     for (int i=0; i< count; i++) {
#         HANDLE_ERROR( cudaGetDeviceProperties( &prop, i ) );
#         printf( "   --- General Information for device %d ---\n", i );
#         printf( "Name:  %s\n", prop.name );
#         printf( "Compute capability:  %d.%d\n", prop.major, prop.minor );
#         printf( "Clock rate:  %d\n", prop.clockRate );
#         printf( "Device copy overlap:  " );
#         if (prop.deviceOverlap)
#             printf( "Enabled\n" );
#         else
#             printf( "Disabled\n");
#         printf( "Kernel execution timeout :  " );
#         if (prop.kernelExecTimeoutEnabled)
#             printf( "Enabled\n" );
#         else
#             printf( "Disabled\n" );
#
#         printf( "   --- Memory Information for device %d ---\n", i );
#         printf( "Total global mem:  %ld\n", prop.totalGlobalMem );
#         printf( "Total constant Mem:  %ld\n", prop.totalConstMem );
#         printf( "Max mem pitch:  %ld\n", prop.memPitch );
#         printf( "Texture Alignment:  %ld\n", prop.textureAlignment );
#
#         printf( "   --- MP Information for device %d ---\n", i );
#         printf( "Multiprocessor count:  %d\n",
#                     prop.multiProcessorCount );
#         printf( "Shared mem per mp:  %ld\n", prop.sharedMemPerBlock );
#         printf( "Registers per mp:  %d\n", prop.regsPerBlock );
#         printf( "Threads in warp:  %d\n", prop.warpSize );
#         printf( "Max threads per block:  %d\n",
#                     prop.maxThreadsPerBlock );
#         printf( "Max thread dimensions:  (%d, %d, %d)\n",
#                     prop.maxThreadsDim[0], prop.maxThreadsDim[1],
#                     prop.maxThreadsDim[2] );
#         printf( "Max grid dimensions:  (%d, %d, %d)\n",
#                     prop.maxGridSize[0], prop.maxGridSize[1],
#                     prop.maxGridSize[2] );
#         printf( "\n" );
#     }
# }
# Out:
# Writing enum_gpu.cu

# %%
# !nvcc enum_gpu.cu

# %%
# !./a.out
# Out:
#    --- General Information for device 0 ---
# Name:  Tesla T4
# Compute capability:  7.5
# Clock rate:  1590000
# Device copy overlap:  Enabled
# Kernel execution timeout :  Disabled
#    --- Memory Information for device 0 ---
# Total global mem:  15843721216
# Total constant Mem:  65536
# Max mem pitch:  2147483647
# Texture Alignment:  512
#    --- MP Information for device 0 ---
# Multiprocessor count:  40
# Shared mem per mp:  49152
# Registers per mp:  65536
# Threads in warp:  32
# Max threads per block:  1024
# Max thread dimensions:  (1024, 1024, 64)
# Max grid dimensions:  (2147483647, 65535, 65535)

# %%
# %%writefile set_gpu.cu
# /*
#  * Copyright 1993-2010 NVIDIA Corporation.  All rights reserved.
#  *
#  * NVIDIA Corporation and its licensors retain all intellectual property and
#  * proprietary rights in and to this software and related documentation.
#  * Any use, reproduction, disclosure, or distribution of this software
#  * and related documentation without an express license agreement from
#  * NVIDIA Corporation is strictly prohibited.
#  *
#  * Please refer to the applicable NVIDIA end user license agreement (EULA)
#  * associated with this source code for terms and conditions that govern
#  * your use of this NVIDIA software.
#  *
#  */
#
#
# #include "book.h"
#
# int main( void ) {
#     cudaDeviceProp  prop;
#     int dev;
#
#     HANDLE_ERROR( cudaGetDevice( &dev ) );
#     printf( "ID of current CUDA device:  %d\n", dev );
#
#     memset( &prop, 0, sizeof( cudaDeviceProp ) );
#     prop.major = 1;
#     prop.minor = 3;
#     HANDLE_ERROR( cudaChooseDevice( &dev, &prop ) );
#     printf( "ID of CUDA device closest to revision 1.3:  %d\n", dev );
#
#     HANDLE_ERROR( cudaSetDevice( dev ) );
# }
# Out:
# Writing set_gpu.cu

# %%
# !nvcc set_gpu.cu

# %%
# !./a.out
# Out:
# ID of current CUDA device:  0
# ID of CUDA device closest to revision 1.3:  0

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/andreinechaev/nvcc4jupyter.git
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-wlnl4r9o
#   Running command git clone -q https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-wlnl4r9o

# %%
# %load_ext nvcc_plugin
# Out:
# The nvcc_plugin extension is already loaded. To reload it, use:
#   %reload_ext nvcc_plugin

# %%
# %%cu
# #include<iostream>
# void c_hello(){
#     printf("Hello World!\n");
# }
#
# int main() {
#     c_hello();
#     return 0;
# }
# Out:
# Hello World!

# %%
# %%cu
# #include<iostream>
# #include<stdio.h>
# using namespace std;
# __global__ void cuda_hello(){
#
#     printf(" hello world from GPU! \n");
#     //cout << "Hello World from GPU!\n";
# }
#
# int main() {
#     cuda_hello<<<1,1>>>();
#     printf(" hello world from main! \n");
#     //cout << "hello world from main!\n";
#     return 0;
# }
# Out:
#  hello world from main!

# %%
# !nvprof --version
# Out:
# nvprof: NVIDIA (R) Cuda command line profiler
# Copyright (c) 2012 - 2020 NVIDIA Corporation
# Release version 11.1.105 (21)
